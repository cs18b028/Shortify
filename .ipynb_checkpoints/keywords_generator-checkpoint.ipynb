# %% [markdown]
# # Importing the required libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
pd.options.mode.chained_assignment = None 

import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\BOBBY\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\BOBBY\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from bs4 import BeautifulSoup
from tqdm import tqdm

tqdm.pandas()

# %%
from collections import Counter
from gensim import corpora
from gensim.models.ldamulticore import LdaMulticore
from pprint import pprint
from gensim.models.coherencemodel import CoherenceModel

# %% [markdown]
# # Importing the datasets

# %%
#The whole dataset is in the data folder in 5 different files
df1 = pd.read_csv('data/original_data1.csv')
df2 = pd.read_csv('data/original_data2.csv')
df3 = pd.read_csv('data/original_data3.csv')
df4 = pd.read_csv('data/original_data4.csv')
df5 = pd.read_csv('data/original_data5.csv')

# %%
#All the different data from differnt datasets is concatenated to form a single dataset
df = pd.concat([df1,df2,df3,df4,df5], axis=0)

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# # Understanding the dataset

# %% [markdown]
# For this model, we want to label the answers, so we will be needing only the 'id', 'tags' and 'answers' columns. Other columns are ignored. The required columns are copied into another dataframe, so the original dataframe can be used when required.

# %%
data = df[['id','tags','answers']]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 3 columns):
# id         100000 non-null int64
# tags       100000 non-null object
# answers    100000 non-null object
# dtypes: int64(1), object(2)
# memory usage: 2.3+ MB

# %%
data.isnull().sum()
# Out:
# id         0
# tags       0
# answers    0
# dtype: int64

# %%
min_ans_len = data['answers'].str.len().min()
max_ans_len = data['answers'].str.len().max()

# %%
data[data['answers'].str.len()==min_ans_len]
# Out:
#             id                          tags                 answers
# 43053  4350260  python|inheritance|decorator  <p>No, it doesn't.</p>

# %%
data[data['answers'].str.len()==max_ans_len]
# Out:
#              id                                       tags  \
# 87503  64587303  python|numpy|image-processing|convolution
#
#                                                  answers
# 87503  <p>I've implemented several very fast solution...

# %% [markdown]
# # Text Processing

# %%
data['tags'] = data['tags'].str.replace('|',' ')
data['tags'] = data['tags'].str.replace('python-3.x','python')
data['tags'] = data['tags'].str.replace('python-2.7','python')

# %%
#def parser(text):
#    soup = BeautifulSoup(text, 'html.parser')
#    while(soup.code):
#        soup.code.decompose()
#    return soup.text

# %%
#removing html tags
data['answers'] = data['answers'].apply(lambda text: BeautifulSoup(text, "lxml").text)

# %%
#converting all letters to lowercase
data['answers'] = data['answers'].str.lower()
data['tags'] = data['tags'].str.lower()

# %%
#removing all punctuations
data['answers'] = data['answers'].str.replace('[^\w\s]',' ')
data['tags'] = data['tags'].str.replace('[^\w\s]',' ')

# %%
data['ans_tokenized'] = data['answers']

# %%
stem_word_list = [('np', 'numpy'), ('plt', 'plot'), ('plt', 'plot'), ('correctly', 'correct'), ('containing', 'contain'), ('better', 'good'),
                  ('best', 'good'), ('strings', 'string'), ('arrays', 'array'), ('variables', 'variable'), ('containing', 'contain'), 
                  ('calls', 'call'), ('called', 'call'), ('calling', 'call'), ('returns', 'return'), ('results', 'result'), ('values', 'value'), 
                  ('val', 'value'), ('images', 'image'), ('img', 'image'), ('png', 'image'), ('tuples', 'tuple'), ('arguments', 'argument'), 
                  ('args', 'argument'), ('argv', 'argument'), ('parameter', 'parameter'), ('params', 'parameter'), ('param', 'parameter'), 
                  ('prints', 'print'), ('lists', 'list'), ('runs', 'run'), ('models', 'model'), ('headers', 'header'), ('installation', 'install'), 
                  ('installed','install'), ('tf','tensorflow'), ('found', 'find'), ('works', 'work'), ('lines', 'line'), ('pd', 'pandas'),
                 ('df', 'dataframe'), ('lib', 'library')]

# %%
for (word, repl_word) in stem_word_list:
    data['ans_tokenized'] = data['ans_tokenized'].str.replace(word, repl_word)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-392-b72149c671b2> in <module>
#       1 for (word, repl_word) in stem_word_list:
# ----> 2     data['ans_tokenized'] = data['ans_tokenized'].str.replace(word, repl_word)
#
# c:\users\bobby\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5173             or name in self._accessors
#    5174         ):
# -> 5175             return object.__getattribute__(self, name)
#    5176         else:
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# c:\users\bobby\appdata\local\programs\python\python37\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     173             # we're accessing the attribute of the class, i.e., Dataset.geo
#     174             return self._accessor
# --> 175         accessor_obj = self._accessor(obj)
#     176         # Replace the property with the accessor object. Inspired by:
#     177         # http://www.pydanny.com/cached-property.html
#
# c:\users\bobby\appdata\local\programs\python\python37\lib\site-packages\pandas\core\strings.py in __init__(self, data)
#    1915
#    1916     def __init__(self, data):
# -> 1917         self._inferred_dtype = self._validate(data)
#    1918         self._is_categorical = is_categorical_dtype(data)
#    1919
#
# c:\users\bobby\appdata\local\programs\python\python37\lib\site-packages\pandas\core\strings.py in _validate(data)
#    1965
#    1966         if inferred_dtype not in allowed_types:
# -> 1967             raise AttributeError("Can only use .str accessor with string " "values!")
#    1968         return inferred_dtype
#    1969
#
# AttributeError: Can only use .str accessor with string values!

# %%
#tokenizing text
data['ans_tokenized'] = data['answers'].apply(lambda text: [word for word in nltk.word_tokenize(text) if word.isalpha()])

# %%
for i in range(0,data.shape[0]):
    data['tags'][i] = data['tags'][i].split(' ')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-393-8bede137b77f> in <module>
#       1 for i in range(0,data.shape[0]):
# ----> 2     data['tags'][i] = data['tags'][i].split(' ')
#
# AttributeError: 'list' object has no attribute 'split'

# %%
#data['ans_tokenized'] = data['ans_tokenized'] + data['tags']

# %%
#lemmatizer = WordNetLemmatizer()
#def lemmatize_text(text):
#    return [lemmatizer.lemmatize(word) for word in text]

# %%
#data['ans_tokenized'].apply(lemmatize_text)

# %%
#function for filtering stop words
def filter_stop_words(words):
    words_filtered = []
    for word in words:
        if word not in stop_words:
            words_filtered.append(word)
    return words_filtered

# %%
nltk.download("stopwords")
stop_words = set(stopwords.words("english"))

data['ans_tokenized'] = data['ans_tokenized'].apply(filter_stop_words)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\BOBBY\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data
# Out:
#              id                                               tags  \
# 0      62766758  [python, pandas, shell, numpy, google, cloud, ...
# 1      62766758  [python, pandas, shell, numpy, google, cloud, ...
# 2      62742938                      [python, modulenotfounderror]
# 3      62741826       [python, pandas, performance, data, science]
# 4      62741826       [python, pandas, performance, data, science]
# ...         ...                                                ...
# 99995  35898687  [python, apache, spark, pyspark, apache, spark...
# 99996  35898687  [python, apache, spark, pyspark, apache, spark...
# 99997  35937882         [python, python, user, interface, tkinter]
# 99998  35937882         [python, python, user, interface, tkinter]
# 99999  35733050  [python, xml, virtual, reality, nuke, adobe, p...
#
#                                                  answers  \
# 0      container optimized os  cos  has several limit...
# 1      i m pretty sure that in case of python librari...
# 2      the standard library has a module runpy for th...
# 3      hello and welcome to stackoverflow \nin pandas...
# 4      i guess you want to groupby and exclude all th...
# ...                                                  ...
# 99995  just for fun non udf solution \nfrom pyspark s...
# 99996  the following code does the requested task  an...
# 99997  at the end of your code  just add window mainl...
# 99998  you didn t do a \nwindow mainloop   \r\n\nat t...
# 99999  whenever faced with a complex xml  consider an...
#
#                                            ans_tokenized
# 0      [container, optimized, os, cos, several, limit...
# 1      [pretty, sure, case, python, libraries, native...
# 2      [standard, library, module, runpy, purpose, ma...
# 3      [hello, welcome, stackoverflow, pandas, rule, ...
# 4      [guess, want, groupby, exclude, elements, appe...
# ...                                                  ...
# 99995  [fun, non, udf, solution, pyspark, sql, functi...
# 99996  [following, code, requested, task, user, defin...
# 99997  [end, code, add, window, mainloop, tells, tkin...
# 99998  [window, mainloop, end, check, tkinter, docs, ...
# 99999  [whenever, faced, complex, xml, consider, xslt...
#
# [100000 rows x 4 columns]

# %%
count = Counter()
def count_tag(answer):
    for word in answer:
        count[word] += 1

# %%
data['ans_tokenized'].apply(count_tag)
len(count.values())
# Out:
# 111816

# %%
word_list = []
for word, cou in count.items():
    if(cou>1000):
        word_list.append(word)

# %%
word_list
# Out:
# ['container',
#  'os',
#  'several',
#  'could',
#  'reason',
#  'program',
#  'work',
#  'system',
#  'running',
#  'many',
#  'linux',
#  'quite',
#  'different',
#  'support',
#  'common',
#  'features',
#  'may',
#  'include',
#  'package',
#  'manager',
#  'install',
#  'packages',
#  'directly',
#  'instance',
#  'non',
#  'third',
#  'modules',
#  'root',
#  'always',
#  'read',
#  'build',
#  'time',
#  'default',
#  'see',
#  'details',
#  'additional',
#  'information',
#  'pretty',
#  'sure',
#  'case',
#  'python',
#  'libraries',
#  'message',
#  'map',
#  'object',
#  'means',
#  'file',
#  'l',
#  'e',
#  'g',
#  'r',
#  'instead',
#  'x',
#  'way',
#  'think',
#  'pip',
#  'flag',
#  'setup',
#  'check',
#  'using',
#  'command',
#  'inside',
#  'set',
#  'remove',
#  'another',
#  'question',
#  'standard',
#  'library',
#  'module',
#  'make',
#  'script',
#  'containing',
#  'import',
#  'true',
#  'equivalent',
#  'sys',
#  'path',
#  'either',
#  'via',
#  'directory',
#  'hello',
#  'pandas',
#  'raw',
#  'loops',
#  'functions',
#  'apply',
#  'function',
#  'sub',
#  'dataframe',
#  'rows',
#  'use',
#  'groupby',
#  'bit',
#  'side',
#  'example',
#  'dictionary',
#  'never',
#  'said',
#  'create',
#  'like',
#  'def',
#  'df',
#  'return',
#  'none',
#  'else',
#  'append',
#  'id',
#  'exactly',
#  'one',
#  'unique',
#  'value',
#  'otherwise',
#  'values',
#  'list',
#  'columns',
#  'contains',
#  'elements',
#  'pass',
#  'guess',
#  'want',
#  'times',
#  'get',
#  'original',
#  'shape',
#  'loc',
#  'count',
#  'correctly',
#  'first',
#  'data',
#  'points',
#  'based',
#  'iterate',
#  'groups',
#  'index',
#  'stuff',
#  'good',
#  'idea',
#  'since',
#  'well',
#  'app',
#  'false',
#  'need',
#  'code',
#  'run',
#  'examples',
#  'csv',
#  'though',
#  'download',
#  'line',
#  'f',
#  'http',
#  'www',
#  'com',
#  'v',
#  'filename',
#  'however',
#  'would',
#  'suggest',
#  'maybe',
#  'best',
#  'thing',
#  'put',
#  'usually',
#  'something',
#  'reader',
#  'open',
#  'next',
#  'header',
#  'url',
#  'assign',
#  'var',
#  'tmp',
#  'break',
#  'try',
#  'source',
#  'str',
#  'string',
#  'pd',
#  'datetime',
#  'date',
#  'year',
#  'astype',
#  'month',
#  'day',
#  'format',
#  'h',
#  'previous',
#  'answer',
#  'syntax',
#  'problem',
#  'requires',
#  'really',
#  'works',
#  'yield',
#  'main',
#  'print',
#  'returned',
#  'generator',
#  'result',
#  'passed',
#  'expect',
#  'believe',
#  'also',
#  'add',
#  'point',
#  'view',
#  'trying',
#  'understand',
#  'keyword',
#  'modified',
#  'still',
#  'normal',
#  'iterator',
#  'difference',
#  'three',
#  'except',
#  'much',
#  'range',
#  'class',
#  'self',
#  'limit',
#  'raise',
#  'control',
#  'call',
#  'context',
#  'variables',
#  'api',
#  'provide',
#  'loop',
#  'must',
#  'around',
#  'calls',
#  'inner',
#  'etc',
#  'lib',
#  'user',
#  'iterable',
#  'able',
#  'change',
#  'hope',
#  'helps',
#  'looks',
#  'simple',
#  'stop',
#  'provided',
#  'called',
#  'stack',
#  'exit',
#  'cases',
#  'exception',
#  'upper',
#  'whatever',
#  'part',
#  'real',
#  'probably',
#  'whole',
#  'look',
#  'say',
#  'needed',
#  'clear',
#  'solution',
#  'better',
#  'basically',
#  'returns',
#  'continue',
#  'uses',
#  'column',
#  'extract',
#  'regex',
#  'named',
#  'expression',
#  'name',
#  'sample',
#  'c',
#  'define',
#  'cols',
#  'test',
#  'compile',
#  'p',
#  'new',
#  'built',
#  'convert',
#  'dt',
#  'write',
#  'results',
#  'output',
#  'items',
#  'address',
#  'find',
#  'reverse',
#  'method',
#  'search',
#  'item',
#  'len',
#  'strings',
#  'error',
#  'version',
#  'model',
#  'network',
#  'operations',
#  'might',
#  'help',
#  'connection',
#  'ip',
#  'strip',
#  'client',
#  'connect',
#  'port',
#  'username',
#  'password',
#  'timeout',
#  'isinstance',
#  'close',
#  'access',
#  'log',
#  'old',
#  'wait',
#  'decode',
#  'logging',
#  'n',
#  'send',
#  'checking',
#  'cmd',
#  'bytes',
#  'utf',
#  'sleep',
#  'split',
#  'needs',
#  'order',
#  'screen',
#  'config',
#  'terminal',
#  'length',
#  'show',
#  'solve',
#  'issue',
#  'approach',
#  'np',
#  'arange',
#  'grid',
#  'array',
#  'reshape',
#  'itertools',
#  'product',
#  'makes',
#  'easier',
#  'repeat',
#  'parameter',
#  'even',
#  'step',
#  'written',
#  'k',
#  'random',
#  'specified',
#  'feature',
#  'without',
#  'size',
#  'objects',
#  'draw',
#  'total',
#  'b',
#  'numpy',
#  'math',
#  'group',
#  'sum',
#  'max',
#  'correct',
#  'people',
#  'person',
#  'second',
#  'together',
#  'axis',
#  'fit',
#  'nan',
#  'takes',
#  'two',
#  'arguments',
#  'consider',
#  'following',
#  'process',
#  'actual',
#  'useful',
#  'calling',
#  'modify',
#  'actually',
#  'adding',
#  'got',
#  'update',
#  'prints',
#  'going',
#  'sense',
#  'know',
#  'mean',
#  'lists',
#  'stored',
#  'form',
#  'empty',
#  'making',
#  'head',
#  'rest',
#  'contents',
#  'language',
#  'used',
#  'implement',
#  'particular',
#  'lst',
#  'end',
#  'found',
#  'everything',
#  'tuples',
#  'integers',
#  'key',
#  'take',
#  'sort',
#  'left',
#  'similar',
#  'hard',
#  'things',
#  'happens',
#  'element',
#  'right',
#  'mentioned',
#  'zero',
#  'go',
#  'special',
#  'done',
#  'give',
#  'back',
#  'course',
#  'writing',
#  'lot',
#  'fact',
#  'already',
#  'static',
#  'types',
#  'interpreter',
#  'kind',
#  'us',
#  'easy',
#  'tell',
#  'io',
#  'figure',
#  'users',
#  'gives',
#  'enough',
#  'versions',
#  'global',
#  'far',
#  'possible',
#  'rather',
#  'bad',
#  'depending',
#  'state',
#  'variable',
#  'words',
#  'exists',
#  'gets',
#  'type',
#  'speed',
#  'scripts',
#  'avoid',
#  'place',
#  'recommend',
#  'py',
#  'lambda',
#  'console',
#  'project',
#  'dir',
#  'copy',
#  'content',
#  'requests',
#  'zip',
#  'select',
#  'entry',
#  'working',
#  'site',
#  'request',
#  'org',
#  'txt',
#  'status',
#  'edit',
#  'https',
#  'github',
#  'service',
#  'changes',
#  'simply',
#  'event',
#  'response',
#  'json',
#  'folder',
#  'local',
#  'machine',
#  'finally',
#  'solved',
#  'structure',
#  'errors',
#  'account',
#  'multiple',
#  'counter',
#  'keep',
#  'counts',
#  'general',
#  'iteration',
#  'single',
#  'enumerate',
#  'google',
#  'starting',
#  'perhaps',
#  'follow',
#  'mask',
#  'pos',
#  'join',
#  'res',
#  'text',
#  'along',
#  'number',
#  'every',
#  'integer',
#  'core',
#  'background',
#  'idx',
#  'int',
#  'letter',
#  'q',
#  'replace',
#  'desired',
#  'numbers',
#  'tag',
#  'encoding',
#  'document',
#  'matches',
#  'match',
#  'start',
#  'note',
#  'u',
#  'javascript',
#  'let',
#  'null',
#  'necessary',
#  'width',
#  'graph',
#  'link',
#  'performance',
#  'last',
#  'pattern',
#  'characters',
#  'choice',
#  'foo',
#  'exist',
#  'please',
#  'abc',
#  'store',
#  'row',
#  'top',
#  'bottom',
#  'input',
#  'enter',
#  'days',
#  'sorted',
#  'calculate',
#  'tests',
#  'collections',
#  'defaultdict',
#  'dict',
#  'task',
#  'nested',
#  'stdin',
#  'likely',
#  'sep',
#  'character',
#  'operator',
#  'less',
#  'anything',
#  'therefore',
#  'changed',
#  'according',
#  'explicitly',
#  'ways',
#  'bool',
#  'testing',
#  'documentation',
#  'whether',
#  'existing',
#  'small',
#  'server',
#  'created',
#  'click',
#  'option',
#  'host',
#  'button',
#  'files',
#  'html',
#  'title',
#  'body',
#  'href',
#  'assuming',
#  'implementation',
#  'names',
#  'extra',
#  'matrix',
#  'load',
#  'memory',
#  'faster',
#  'available',
#  'reduce',
#  'given',
#  'chain',
#  'fine',
#  'assert',
#  'large',
#  'big',
#  'ones',
#  'keys',
#  'location',
#  'argv',
#  'parser',
#  'elif',
#  'args',
#  'reference',
#  'description',
#  'seems',
#  'wrong',
#  'num',
#  'yes',
#  'block',
#  'execute',
#  'condition',
#  'statement',
#  'w',
#  'findall',
#  'thanks',
#  'boolean',
#  'required',
#  'sequence',
#  'traceback',
#  'separate',
#  'generate',
#  'demo',
#  'col',
#  'val',
#  'valid',
#  'image',
#  'png',
#  'color',
#  'mode',
#  'zeros',
#  'fill',
#  'white',
#  'params',
#  'msg',
#  'offset',
#  'later',
#  'super',
#  'page',
#  'little',
#  'fix',
#  'getting',
#  'looking',
#  'section',
#  'added',
#  'unless',
#  'argument',
#  'span',
#  'widget',
#  'kwargs',
#  'lines',
#  'ok',
#  'label',
#  'font',
#  'tkinter',
#  'master',
#  'tk',
#  'height',
#  'arrays',
#  'allow',
#  'buffer',
#  'operation',
#  'options',
#  'creating',
#  'outside',
#  'least',
#  'made',
#  'expected',
#  'comment',
#  'target',
#  'regular',
#  'glob',
#  'filter',
#  'z',
#  'word',
#  'digits',
#  'perform',
#  'post',
#  'matplotlib',
#  'pyplot',
#  'plt',
#  'plot',
#  'commands',
#  'creates',
#  'valueerror',
#  'thread',
#  'driver',
#  'changing',
#  'tried',
#  'threading',
#  'beautifulsoup',
#  'webdriver',
#  'selenium',
#  'chrome',
#  'images',
#  'urls',
#  'exe',
#  'soup',
#  'nothing',
#  'tuple',
#  'child',
#  'attribute',
#  'tags',
#  'parse',
#  'doc',
#  'en',
#  'latest',
#  'processes',
#  'login',
#  'stdout',
#  'complete',
#  'threads',
#  'issues',
#  'logic',
#  'related',
#  'environment',
#  'pygame',
#  'window',
#  'comments',
#  'high',
#  'usage',
#  'thus',
#  'current',
#  'unicode',
#  'encode',
#  'position',
#  'short',
#  'settings',
#  'frame',
#  'passing',
#  'within',
#  'level',
#  'application',
#  'assume',
#  'env',
#  'parameters',
#  'django',
#  'docs',
#  'dev',
#  'template',
#  'future',
#  'fields',
#  'field',
#  'div',
#  'delete',
#  'custom',
#  'style',
#  'double',
#  'layer',
#  'setting',
#  'display',
#  'func',
#  'indices',
#  'dtype',
#  'signal',
#  'subprocess',
#  'methods',
#  'shell',
#  'popen',
#  'easily',
#  'handle',
#  'long',
#  'fixed',
#  'final',
#  'cell',
#  'compare',
#  'info',
#  'drop',
#  'although',
#  'wanted',
#  'processing',
#  'meta',
#  'callback',
#  'xpath',
#  'yet',
#  'category',
#  'img',
#  'src',
#  'home',
#  'save',
#  'writer',
#  'missing',
#  'updated',
#  'lower',
#  'bar',
#  'web',
#  'worked',
#  'flask',
#  'world',
#  'automatically',
#  'rename',
#  'runs',
#  'browser',
#  'query',
#  'reading',
#  'scope',
#  'token',
#  'definition',
#  'headers',
#  'session',
#  'models',
#  'admin',
#  'installed',
#  'entire',
#  'parts',
#  'debug',
#  'classes',
#  'cls',
#  'defined',
#  'timeit',
#  'specific',
#  'initial',
#  'space',
#  'net',
#  'db',
#  'database',
#  'sql',
#  'manually',
#  'table',
#  'engine',
#  'specify',
#  'price',
#  'decimal',
#  'pop',
#  'pi',
#  'rect',
#  'socket',
#  'java',
#  'mylist',
#  'algorithm',
#  'slice',
#  'usr',
#  'bin',
#  'binary',
#  'float',
#  'tr',
#  'answers',
#  'windows',
#  'pipe',
#  'contain',
#  'pdf',
#  'dates',
#  'nodes',
#  'interface',
#  'iloc',
#  'attributes',
#  'cat',
#  'red',
#  'blue',
#  'country',
#  'urllib',
#  'randint',
#  'diff',
#  'player',
#  'problems',
#  'action',
#  'pack',
#  'char',
#  'temp',
#  'obj',
#  'axes',
#  'fig',
#  'move',
#  'distance',
#  'ax',
#  'spaces',
#  'full',
#  'follows',
#  'node',
#  'vector',
#  'instances',
#  'base',
#  'seconds',
#  'jpg',
#  'j',
#  'allows',
#  'property',
#  'series',
#  'tree',
#  'stream',
#  'keras',
#  'tensorflow',
#  'dataset',
#  'comprehension',
#  'sentence',
#  'arr',
#  'per',
#  'canvas',
#  'efficient',
#  'virtualenv',
#  'sudo',
#  'box',
#  'cursor',
#  'views',
#  'insert',
#  'li',
#  'concat',
#  'steps',
#  'shift',
#  'children',
#  'amount',
#  'labels',
#  'parent',
#  'age',
#  'min',
#  'sets',
#  'scipy',
#  'merge',
#  'qtcore',
#  'timestamp',
#  'wx',
#  'bind',
#  'job',
#  'qtgui',
#  'equal',
#  'email',
#  'score',
#  'xml',
#  'center',
#  'multiprocessing',
#  'queue',
#  'render',
#  'transform',
#  'apple',
#  'ms',
#  'record',
#  'pool',
#  'tf',
#  'weight',
#  'turtle',
#  'td',
#  'conda',
#  'std',
#  'train']

# %% [markdown]
# Some of the words are not useful, which are therefore added to the list of 'stop_words' and again the answer text is filtered.

# %%
stop_words.update(['several', 'could', 'many', 'may', 'non', 'quite', 'v', 'l', 'e', 'g', 'rw', 'r', 'xr', 'x', 'rwxr', 'think',
                   'sane', 'hello', 'welcome', 'still', 'normal', 'much', 'c', 'p', 'n', 'k', 'b', 'h', 'lot', 'us', 'kind', 
                   'q', 'w', 'z', 'en', 'ax', 'j', 'python', 'code', 'using', 'need', 'get', 'py', 'u', 'keep', 'general', 
                   'also', 'really', 'normal', 'able', 'maybe', 'things', 'everything', 'happens', 'actually', 'lst', 'already',
                  'within', 'li', 'python', 'based', 'user', 'np', 'pd', 'tf', 'id'])

# %%
data['ans_tokenized'] = data['ans_tokenized'].apply(filter_stop_words)

# %%
answers = data['ans_tokenized']

# %%
answers
# Out:
# 0        [container, optimized, os, cos, limitations, r...
# 1        [pretty, sure, case, libraries, natives, messa...
# 2        [standard, library, module, runpy, purpose, ma...
# 3        [stackoverflow, pandas, rule, thumb, raw, loop...
# 4        [guess, want, groupby, exclude, elements, appe...
#                                ...
# 99995    [fun, udf, solution, pyspark, sql, functions, ...
# 99996    [following, requested, task, defined, function...
# 99997    [end, add, window, mainloop, tells, tkinter, f...
# 99998    [window, mainloop, end, check, tkinter, docs, ...
# 99999    [whenever, faced, complex, xml, consider, xslt...
# Name: ans_tokenized, Length: 100000, dtype: object

# %% [markdown]
# # Building the model

# %%
#Create dictionary and corpus
id2word = corpora.Dictionary(answers)
corpus = [id2word.doc2bow(answer) for answer in answers]

# %%
#Building an lda model
ldamodel = LdaMulticore(corpus=corpus, num_topics=5, id2word=id2word, passes=5)

# %%
pprint(ldamodel.show_topics(formatted=False))

# %%
ldamodel.log_perplexity(corpus)

# %%
coherence_lda = CoherenceModel(model=ldamodel, texts=answers, dictionary=id2word, coherence='c_v')
score = coherence_lda.get_coherence()

# %%
print("Coherence score of lda model: ",score)

# %%
#Building LDA Mallet model
import os
from gensim.models.wrappers import LdaMallet
os.environ['MALLET_HOME'] = 'C:\\Users\\BOBBY\\Downloads\\mallet-2.0.8'
mallet_path = 'C:\\Users\\BOBBY\\Downloads\\mallet-2.0.8\\bin\\mallet'

# %%
ldamallet_model = LdaMallet(mallet_path, corpus=corpus, num_topics=8, id2word=id2word)

# %%
pprint(ldamallet_model.show_topics(formatted=False))
# Out:
# [(0,
#   [('def', 0.04859744939563604),
#    ('return', 0.04838610253492947),
#    ('function', 0.037508784103898116),
#    ('class', 0.02836627115449984),
#    ('object', 0.024669462315974125),
#    ('method', 0.01960066010669494),
#    ('call', 0.015262765790692636),
#    ('test', 0.013760441855836783),
#    ('type', 0.013707605140660143),
#    ('variable', 0.011470850864848966)]),
#  (1,
#   [('print', 0.057633383173792484),
#    ('list', 0.05469433754151231),
#    ('string', 0.027473910831821848),
#    ('key', 0.023729881838719016),
#    ('append', 0.020684646912032447),
#    ('input', 0.017896321568587153),
#    ('number', 0.0178860451852575),
#    ('len', 0.017397916977099078),
#    ('split', 0.016043147108140095),
#    ('item', 0.0160106052275962)]),
#  (2,
#   [('time', 0.02124062315766648),
#    ('problem', 0.00985119027451193),
#    ('process', 0.008411205453646042),
#    ('work', 0.008101185192212562),
#    ('run', 0.007711542240684145),
#    ('question', 0.007005102628565233),
#    ('answer', 0.0069898557304619476),
#    ('start', 0.006872962845003422),
#    ('server', 0.006757764059334151),
#    ('message', 0.00664256527366488)]),
#  (3,
#   [('file', 0.04644706664688395),
#    ('line', 0.0353121408052398),
#    ('path', 0.023374585054637825),
#    ('open', 0.020469744070102304),
#    ('import', 0.019229153520399136),
#    ('os', 0.017221684950778585),
#    ('write', 0.01388782129775782),
#    ('read', 0.013372994095575526),
#    ('install', 0.01331042828975476),
#    ('csv', 0.012650805936958694)]),
#  (4,
#   [('text', 0.025158293283225528),
#    ('import', 0.023275235582964952),
#    ('def', 0.023014257436873402),
#    ('root', 0.01161151997687332),
#    ('add', 0.010236365899390917),
#    ('match', 0.01003360595511979),
#    ('set', 0.00979671809943669),
#    ('end', 0.00935707029948246),
#    ('event', 0.009298852097662038),
#    ('true', 0.00845769945756696)]),
#  (5,
#   [('df', 0.06446446891181246),
#    ('true', 0.034868692090829045),
#    ('data', 0.0294705678027029),
#    ('index', 0.028523422164419637),
#    ('false', 0.027055245450065837),
#    ('pd', 0.023892707988335368),
#    ('values', 0.02034646547058396),
#    ('row', 0.019290266816378954),
#    ('nan', 0.018989361272446745),
#    ('dataframe', 0.016339776885607425)]),
#  (6,
#   [('https', 0.01755469865144123),
#    ('id', 0.017210280008805756),
#    ('import', 0.01610068386629455),
#    ('html', 0.015523693872188727),
#    ('data', 0.014758516372313003),
#    ('http', 0.013849535212367824),
#    ('request', 0.01374301398268675),
#    ('url', 0.012329832335584483),
#    ('json', 0.01210968846091026),
#    ('django', 0.011097736778940043)]),
#  (7,
#   [('np', 0.04450068659245625),
#    ('array', 0.02533818330557747),
#    ('import', 0.023632658427557192),
#    ('data', 0.01841930347386566),
#    ('numpy', 0.016476392906185175),
#    ('random', 0.014383746749642096),
#    ('plt', 0.013448812341134193),
#    ('image', 0.011162605545329711),
#    ('size', 0.009097350045285885),
#    ('range', 0.00848562538346919)])]

# %%
coherence_ldamallet = CoherenceModel(model=ldamallet_model, texts=answers, dictionary=id2word, coherence='c_v')
score = coherence_ldamallet.get_coherence()

# %%
print("Coherence score of lda mallet model: ",score)
# Out:
# Coherence score of lda mallet model:  0.5901525301797624

# %% [markdown]
# By comparing the scores, it is clearly evident that LDA Mallet model works better that LDA multicore model. We can use LDA mallet model and find optimal number of topics.

# %% [markdown]
# # Finding optimal number of topics

# %%
def coh_value(id2word, corpus, answers, start, stop, step):
    coh_values_list = []
    model_list = []
    for num_topics in range(start, stop, step):
        model = LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=id2word)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=answers, dictionary=id2word, coherence='c_v')
        coh_values_list.append(coherencemodel.get_coherence())
        print(num_topics)
    return model_list, coh_values_list

# %%
start = 2
stop = 20
step = 2

# %%
model_list, coh_values_list = coh_value(id2word, corpus, answers, start, stop, step)
# Out:
# 2
# 4
# 6
# 8
# 10
# 12
# 14
# 16
# 18

# %%
topic_num = range(start, stop, step)
plt.plot(topic_num, coh_values_list)
plt.title("Coherence value score for the number of topics")
plt.xlabel("No. of Topics")
plt.ylabel("Coherence score")
#plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
for i in range(start, stop, step):
    print("No. of topics:  ", i, ", Coherence Value: ", coh_values_list[(i-start)//2])
# Out:
# No. of topics:   2 , Coherence Value:  0.4095438810466185
# No. of topics:   4 , Coherence Value:  0.5342842390038446
# No. of topics:   6 , Coherence Value:  0.5682253615521279
# No. of topics:   8 , Coherence Value:  0.5837369851009455
# No. of topics:   10 , Coherence Value:  0.6068811678520329
# No. of topics:   12 , Coherence Value:  0.6149607929334713
# No. of topics:   14 , Coherence Value:  0.6138146710755172
# No. of topics:   16 , Coherence Value:  0.6174509538255538
# No. of topics:   18 , Coherence Value:  0.6161918846495307

# %%
final_model = model_list[3]
model_topics = final_model.show_topics(formatted=False)
pprint(final_model.print_topics(num_words=10))
# Out:
# [(0,
#   '0.049*"def" + 0.048*"return" + 0.038*"function" + 0.028*"class" + '
#   '0.025*"object" + 0.020*"method" + 0.015*"call" + 0.014*"test" + '
#   '0.014*"type" + 0.011*"variable"'),
#  (1,
#   '0.058*"print" + 0.055*"list" + 0.027*"string" + 0.024*"key" + '
#   '0.021*"append" + 0.018*"input" + 0.018*"number" + 0.017*"len" + '
#   '0.016*"split" + 0.016*"item"'),
#  (2,
#   '0.021*"time" + 0.010*"problem" + 0.008*"process" + 0.008*"work" + '
#   '0.008*"run" + 0.007*"question" + 0.007*"answer" + 0.007*"start" + '
#   '0.007*"server" + 0.007*"message"'),
#  (3,
#   '0.046*"file" + 0.035*"line" + 0.023*"path" + 0.020*"open" + 0.019*"import" '
#   '+ 0.017*"os" + 0.014*"write" + 0.013*"read" + 0.013*"install" + '
#   '0.013*"csv"'),
#  (4,
#   '0.025*"text" + 0.023*"import" + 0.023*"def" + 0.012*"root" + 0.010*"add" + '
#   '0.010*"match" + 0.010*"set" + 0.009*"end" + 0.009*"event" + 0.008*"true"'),
#  (5,
#   '0.064*"df" + 0.035*"true" + 0.029*"data" + 0.029*"index" + 0.027*"false" + '
#   '0.024*"pd" + 0.020*"values" + 0.019*"row" + 0.019*"nan" + '
#   '0.016*"dataframe"'),
#  (6,
#   '0.018*"https" + 0.017*"id" + 0.016*"import" + 0.016*"html" + 0.015*"data" + '
#   '0.014*"http" + 0.014*"request" + 0.012*"url" + 0.012*"json" + '
#   '0.011*"django"'),
#  (7,
#   '0.045*"np" + 0.025*"array" + 0.024*"import" + 0.018*"data" + 0.016*"numpy" '
#   '+ 0.014*"random" + 0.013*"plt" + 0.011*"image" + 0.009*"size" + '
#   '0.008*"range"')]

# %%
topics = final_model[corpus]

# %%
topics
# Out:
# [[(0, 0.06276371308016879),
#   (1, 0.040260196905766536),
#   (2, 0.324367088607595),
#   (3, 0.314521800281294),
#   (4, 0.05854430379746836),
#   (5, 0.039556962025316465),
#   (6, 0.07401547116736991),
#   (7, 0.08597046413502112)],
#  [(0, 0.11531007751937984),
#   (1, 0.10109819121447028),
#   (2, 0.1605297157622739),
#   (3, 0.23417312661498707),
#   (4, 0.14114987080103358),
#   (5, 0.08301033591731266),
#   (6, 0.07396640826873385),
#   (7, 0.09076227390180878)],
#  [(0, 0.10555555555555556),
#   (1, 0.08925925925925926),
#   (2, 0.1411111111111111),
#   (3, 0.27296296296296296),
#   (4, 0.11),
#   (5, 0.10703703703703704),
#   (6, 0.0862962962962963),
#   (7, 0.08777777777777777)],
#  [(0, 0.1787749287749288),
#   (1, 0.12559354226020894),
#   (2, 0.1103988603988604),
#   (3, 0.0600664767331434),
#   (4, 0.09710351377018044),
#   (5, 0.2851377018043685),
#   (6, 0.08000949667616335),
#   (7, 0.06291547958214624)],
#  [(0, 0.09702093397745572),
#   (1, 0.12600644122383253),
#   (2, 0.10668276972624799),
#   (3, 0.09057971014492754),
#   (4, 0.09702093397745572),
#   (5, 0.23711755233494364),
#   (6, 0.11151368760064412),
#   (7, 0.13405797101449277)],
#  [(0, 0.11405228758169936),
#   (1, 0.1062091503267974),
#   (2, 0.13496732026143793),
#   (3, 0.08137254901960786),
#   (4, 0.08137254901960786),
#   (5, 0.2866013071895425),
#   (6, 0.09705882352941178),
#   (7, 0.09836601307189544)],
#   (5, 0.11159003831417626),
#   (6, 0.10775862068965518),
#   (7, 0.10775862068965518)],
#  [(0, 0.10964912280701754),
#   (1, 0.10964912280701754),
#   (2, 0.17982456140350878),
#   (3, 0.11354775828460038),
#   (4, 0.11744639376218323),
#   (5, 0.10964912280701754),
#   (6, 0.15058479532163743),
#   (7, 0.10964912280701754)],
#  [(0, 0.09880450070323489),
#   (1, 0.08614627285513363),
#   (2, 0.23804500703234882),
#   (3, 0.18037974683544306),
#   (4, 0.0819268635724332),
#   (5, 0.12834036568213786),
#   (6, 0.09739803094233475),
#   (7, 0.08895921237693391)],
#  [(0, 0.11346516007532957),
#   (1, 0.1059322033898305),
#   (2, 0.1925612052730697),
#   (3, 0.11346516007532957),
#   (4, 0.12099811676082863),
#   (5, 0.1059322033898305),
#   (6, 0.1379472693032015),
#   (7, 0.10969868173258004)],
#  [(0, 0.16907051282051283),
#   (1, 0.09428418803418803),
#   (2, 0.09748931623931624),
#   (3, 0.2759081196581197),
#   (4, 0.1295405982905983),
#   (5, 0.08253205128205128),
#   (6, 0.08466880341880342),
#   (7, 0.06650641025641026)],
#  [(0, 0.10821759259259259),
#   (1, 0.11902006172839506),
#   (2, 0.26948302469135804),
#   (3, 0.2532793209876543),
#   (4, 0.07040895061728394),
#   (5, 0.0626929012345679),
#   (6, 0.058834876543209874),
#   (7, 0.05806327160493827)],
#  [(0, 0.11968954248366014),
#   (1, 0.10661764705882353),
#   (2, 0.17851307189542484),
#   (3, 0.09681372549019608),
#   (4, 0.12295751633986927),
#   (5, 0.11151960784313726),
#   (6, 0.14256535947712418),
#   (7, 0.1213235294117647)],
#  [(0, 0.1501937984496124),
#   (1, 0.11401808785529716),
#   (2, 0.14631782945736435),
#   (3, 0.1101421188630491),
#   (4, 0.10109819121447028),
#   (5, 0.09593023255813954),
#   (6, 0.20574935400516794),
#   (7, 0.07655038759689922)],
#  [(0, 0.18462059620596205),
#   (1, 0.08299457994579945),
#   (2, 0.11415989159891599),
#   (3, 0.16294037940379405),
#   (4, 0.13584010840108401),
#   (5, 0.07892953929539295),
#   (6, 0.14532520325203252),
#   (7, 0.09518970189701897)],
#  [(0, 0.12922705314009664),
#   (1, 0.09380032206119164),
#   (2, 0.14855072463768118),
#   (3, 0.1243961352657005),
#   (4, 0.19363929146537845),
#   (5, 0.09702093397745573),
#   (6, 0.09380032206119164),
#   (7, 0.11956521739130437)],
#  ...]

# %%
topic_df = pd.DataFrame()

# %%
for i, topic_vector in enumerate(topics):
    print(i)
    topic_keyword_list = []
    topic_vector = sorted(topic_vector, key = lambda topic: (topic[1]), reverse=True)
    topic_num = topic_vector[0][0]
    prob = topic_vector[0][1]
    prob = round(prob,2) * 100
    main_topic = final_model.show_topic(topic_num)
    topic_keywords = ", ".join([word for word, prop in main_topic])
    print(topic_keywords)
    break
    topic_df = topic_df.append(pd.Series([df.iloc[i]['id'], df.iloc[i]['answers'], topic_keyword_list]), ignore_index=True)

# %%
topic_df

# %%
topic_df.to_csv('data/keyword_answer.csv', index=False)
