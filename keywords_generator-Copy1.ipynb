# %% [markdown]
# # Importing the required libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
pd.options.mode.chained_assignment = None 

import string
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\BOBBY\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\BOBBY\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from bs4 import BeautifulSoup
from tqdm import tqdm

tqdm.pandas()
# Out:
# c:\users\bobby\appdata\local\programs\python\python37\lib\site-packages\tqdm\std.py:725: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
from collections import Counter
from gensim import corpora
from gensim.models.ldamulticore import LdaMulticore
from pprint import pprint
from gensim.models.coherencemodel import CoherenceModel

# %%
import os
from gensim.models.wrappers import LdaMallet
os.environ['MALLET_HOME'] = 'C:\\Users\\BOBBY\\Downloads\\mallet-2.0.8'
mallet_path = 'C:\\Users\\BOBBY\\Downloads\\mallet-2.0.8\\bin\\mallet'

# %% [markdown]
# # Importing the datasets

# %%
#The whole dataset is in the data folder in 5 different files
df1 = pd.read_csv('data/original_data1.csv')
df2 = pd.read_csv('data/original_data2.csv')
df3 = pd.read_csv('data/original_data3.csv')
df4 = pd.read_csv('data/original_data4.csv')
df5 = pd.read_csv('data/original_data5.csv')

# %%
#All the different data from differnt datasets is concatenated to form a single dataset
df = pd.concat([df1,df2,df3,df4,df5], axis=0)

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#              id                                              title  \
# 0      62766758  How to fix Python error "...failed to map segm...
# 1      62766758  How to fix Python error "...failed to map segm...
# 2      62742938                    Wrapper for 'python -m' command
# 3      62741826  How can I improve the speed of pandas rows ope...
# 4      62741826  How can I improve the speed of pandas rows ope...
# ...         ...                                                ...
# 99995  35898687  Adding column to PySpark DataFrame depending o...
# 99996  35898687  Adding column to PySpark DataFrame depending o...
# 99997  35937882                        Simple Window using TkInter
# 99998  35937882                        Simple Window using TkInter
# 99999  35733050  Python Parsing XML with a complex hierarchy - ...
#
#                                                     body  \
# 0      <p>I've recently started to use Google Cloud P...
# 1      <p>I've recently started to use Google Cloud P...
# 2      <p>I have a package with following structure:<...
# 3      <p>I have a large .csv file that has 11'000'00...
# 4      <p>I have a large .csv file that has 11'000'00...
# ...                                                  ...
# 99995  <p>I have a PySpark DataFrame with structure g...
# 99996  <p>I have a PySpark DataFrame with structure g...
# 99997  <p>I'm new to <code>TkInter</code> and using P...
# 99998  <p>I'm new to <code>TkInter</code> and using P...
# 99999  <p>I am working with NukeX9.0v8, Adobe Premier...
#
#                                                     tags  \
# 0      python-3.x|pandas|shell|numpy|google-cloud-pla...
# 1      python-3.x|pandas|shell|numpy|google-cloud-pla...
# 2                             python|modulenotfounderror
# 3                 python|pandas|performance|data-science
# 4                 python|pandas|performance|data-science
# ...                                                  ...
# 99995       python|apache-spark|pyspark|apache-spark-sql
# 99996       python|apache-spark|pyspark|apache-spark-sql
# 99997           python|python-2.7|user-interface|tkinter
# 99998           python|python-2.7|user-interface|tkinter
# 99999     python|xml|virtual-reality|nuke|adobe-premiere
#
#                                                  answers  score
# 0      <p>Container-Optimized OS (COS) has several li...      1
# 1      <p>I'm pretty sure that in case of Python libr...      0
# 2      <p>The standard library has a module <a href="...      1
# 3      <p>Hello and welcome to StackOverflow.</p>\r\n...      1
# 4      <p>I guess you want to <code>groupby</code> an...      0
# ...                                                  ...    ...
# 99995  <p>Just for fun non-UDF solution:</p>\r\n\r\n<...      3
# 99996  <p>The following code does the requested task....      7
# 99997  <p>At the end of your code, just add <code>win...      2
# 99998  <p>You didn't do a </p>\r\n\r\n<pre><code>wind...      5
# 99999  <p>Whenever faced with a complex XML, consider...      0
#
# [100000 rows x 6 columns]

# %% [markdown]
# # Understanding the dataset

# %% [markdown]
# For this model, we want to label the answers, so we will be needing only the 'id', 'tags' and 'answers' columns. Other columns are ignored. The required columns are copied into another dataframe, so the original dataframe can be used when required.

# %%
data = df[['id','tags','answers']]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 3 columns):
# id         100000 non-null int64
# tags       100000 non-null object
# answers    100000 non-null object
# dtypes: int64(1), object(2)
# memory usage: 2.3+ MB

# %%
data.isnull().sum()
# Out:
# id         0
# tags       0
# answers    0
# dtype: int64

# %%
min_ans_len = data['answers'].str.len().min()
max_ans_len = data['answers'].str.len().max()

# %%
data[data['answers'].str.len()==min_ans_len]
# Out:
#             id                          tags                 answers
# 43053  4350260  python|inheritance|decorator  <p>No, it doesn't.</p>

# %%
data[data['answers'].str.len()==max_ans_len]
# Out:
#              id                                       tags  \
# 87503  64587303  python|numpy|image-processing|convolution
#
#                                                  answers
# 87503  <p>I've implemented several very fast solution...

# %% [markdown]
# # Text Processing

# %%
data['tags'] = data['tags'].str.replace('|',' ')
data['tags'] = data['tags'].str.replace('python-3.x','python')
data['tags'] = data['tags'].str.replace('python-2.7','python')

# %%
#def parser(text):
#    soup = BeautifulSoup(text, 'html.parser')
#    while(soup.code):
#        soup.code.decompose()
#    return soup.text

# %%
def extract_text(text):
    soup = BeautifulSoup(text, 'lxml')
    txt = "".join([txt.text for txt in soup.find_all("p")])
    return txt

# %%
def extract_link(text):
    soup = BeautifulSoup(text, 'lxml')
    link = " ".join([link['href'] for link in soup.find_all("a")])
    return link

# %%
def extract_code(text):
    soup = BeautifulSoup(text, 'lxml')
    code = "\n".join([code.text for code in soup.find_all("code")])
    return code

# %%
#extracting text
data['text'] = data['answers'].apply(extract_text)
#extracting links
data['link'] = data['answers'].apply(extract_link)
#extracting links
data['code'] = data['answers'].apply(extract_code)

# %%
df['body'] = df['body'].apply(extract_text)

# %%
data['ans_tokenized'] = data['text']

# %%
#converting all letters to lowercase
data['ans_tokenized'] = data['ans_tokenized'].str.lower()
data['tags'] = data['tags'].str.lower()

# %%
#removing all punctuations
data['ans_tokenized'] = data['ans_tokenized'].str.translate(str.maketrans("", "", string.punctuation))
data['tags'] = data['tags'].str.translate(str.maketrans("", "", string.punctuation))

# %%
data
# Out:
#              id                                           tags  \
# 0      62766758  python pandas shell numpy googlecloudplatform
# 1      62766758  python pandas shell numpy googlecloudplatform
# 2      62742938                     python modulenotfounderror
# 3      62741826          python pandas performance datascience
# 4      62741826          python pandas performance datascience
# ...         ...                                            ...
# 99995  35898687      python apachespark pyspark apachesparksql
# 99996  35898687      python apachespark pyspark apachesparksql
# 99997  35937882            python python userinterface tkinter
# 99998  35937882            python python userinterface tkinter
# 99999  35733050   python xml virtualreality nuke adobepremiere
#
#                                                  answers  \
# 0      <p>Container-Optimized OS (COS) has several li...
# 1      <p>I'm pretty sure that in case of Python libr...
# 2      <p>The standard library has a module <a href="...
# 3      <p>Hello and welcome to StackOverflow.</p>\r\n...
# 4      <p>I guess you want to <code>groupby</code> an...
# ...                                                  ...
# 99995  <p>Just for fun non-UDF solution:</p>\r\n\r\n<...
# 99996  <p>The following code does the requested task....
# 99997  <p>At the end of your code, just add <code>win...
# 99998  <p>You didn't do a </p>\r\n\r\n<pre><code>wind...
# 99999  <p>Whenever faced with a complex XML, consider...
#
#                                                     text  \
# 0      Container-Optimized OS (COS) has several limit...
# 1      I'm pretty sure that in case of Python librari...
# 2      The standard library has a module runpy for th...
# 3      Hello and welcome to StackOverflow.In pandas t...
# 4      I guess you want to groupby and exclude all th...
# ...                                                  ...
# 99995  Just for fun non-UDF solution:So it just:unrol...
# 99996  The following code does the requested task. An...
# 99997  At the end of your code, just add window.mainl...
# 99998  You didn't do a at the end. Check the Tkinter ...
# 99999  Whenever faced with a complex XML, consider an...
#
#                                                     link  \
# 0      https://cloud.google.com/container-optimized-o...
# 1
# 2           https://docs.python.org/3/library/runpy.html
# 3
# 4
# ...                                                  ...
# 99995
# 99996
# 99997
# 99998     https://docs.python.org/2/library/tkinter.html
# 99999         https://www.w3.org/TR/xslt http://lxml.de/
#
#                                                     code  \
# 0
# 1      failed to map segment from shared object\n.so\...
# 2      runpy\nimport runpy\r\nrunpy.run_module("my_pa...
# 3      groupby\nS\nIn [37]: def my_func(df): \r\n    ...
# 4      groupby\nmixid2\nset_index\nreset_index\ndf = ...
# ...                                                  ...
# 99995  from pyspark.sql.functions import col, first, ...
# 99996  DataFrame\n# Imports\r\nfrom pyspark.sql.types...
# 99997                                  window.mainloop()
# 99998                             window.mainloop() \r\n
# 99999  <xsl:transform xmlns:xsl="http://www.w3.org/19...
#
#                                            ans_tokenized
# 0      containeroptimized os cos has several limitati...
# 1      im pretty sure that in case of python librarie...
# 2      the standard library has a module runpy for th...
# 3      hello and welcome to stackoverflowin pandas th...
# 4      i guess you want to groupby and exclude all th...
# ...                                                  ...
# 99995  just for fun nonudf solutionso it justunrolls ...
# 99996  the following code does the requested task an ...
# 99997  at the end of your code just add windowmainloo...
# 99998  you didnt do a at the end check the tkinter do...
# 99999  whenever faced with a complex xml consider an ...
#
# [100000 rows x 7 columns]

# %%
stem_word_list = [('np ', 'numpy '), ('plt', 'plot'), ('correctly', 'correct'), ('containing', 'contain'), ('better', 'good'),
                  ('best', 'good'), ('strings', 'string'), ('arrays', 'array'), ('variables', 'variable'), ('calls', 'call'), 
                  ('called', 'call'), ('calling', 'call'), ('returns', 'return'), ('results', 'result'), ('values', 'value'), 
                  ('val ', 'value '), ('images', 'image'), ('img', 'image'), ('png', 'image'), ('tuples', 'tuple'), ('arguments', 'argument'), 
                  ('args', 'argument'), ('argv', 'argument'), ('parameters ', 'parameter'), ('params ', 'parameter'), ('param ', 'parameter'), 
                  ('prints', 'print'), ('lists', 'list'), ('runs', 'run'), ('models', 'model'), ('headers', 'header'), ('installation', 'install'), 
                  ('installed','install'), ('tf','tensorflow'), ('found', 'find'), ('lines', 'line'), ('pd', 'pandas'), 
                  ('df', 'dataframe'), ('lib ', 'library '), ('https', 'http'), ('works', 'work'), ('classes', 'class'), 
                  ('follows', 'follow'), ('numbers', 'number'), ('points', 'point'), ('dict ', 'dictionary'), ('characters', 'character'),
                  ('keys', 'key'), ('bytes', 'byte'), ('str ', 'string'), ('objects', 'objects'), ('methods', 'method'),
                 ('rows', 'row'), ('defined', 'define'), ('cases', 'case'), ('names', 'name'), ('helps', 'help')]

# %%
for (word, repl_word) in stem_word_list:
    data['ans_tokenized'] = data['ans_tokenized'].str.replace(word, repl_word)

# %%
nltk.download("stopwords")
stop_words = set(stopwords.words("english"))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\BOBBY\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
docs = data['ans_tokenized'].tolist()

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

cv = CountVectorizer(max_df=0.65, stop_words = stop_words)
word_count_vector = cv.fit_transform(docs)

# %%
tfidf_transformer = TfidfTransformer(smooth_idf=True,use_idf=True)
tfidf_transformer.fit_transform(word_count_vector)
# Out:
# <100000x99911 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2302435 stored elements in Compressed Sparse Row format>

# %%
df_idf = pd.DataFrame(tfidf_transformer.idf_, index=cv.get_feature_names(), columns=["idf_weights"]) 
df_idf.sort_values(by=['idf_weights'])
# Out:
#             idf_weights
# use            2.170355
# using          2.692341
# python         2.723961
# like           2.730430
# code           2.808814
# ...                 ...
# github3       11.819788
# githomelab    11.819788
# githb         11.819788
# githubhttp    11.819788
# ｊａｖａｓｃｒｉｐｔ    11.819788
#
# [99911 rows x 1 columns]

# %%
#tokenizing text
data['ans_tokenized'] = data['ans_tokenized'].apply(lambda text: [word for word in nltk.word_tokenize(text) if word.isalpha()])

# %%
for i in range(0,data.shape[0]):
    data['tags'][i] = data['tags'][i].split(' ')

# %%
#function for filtering stop words
def filter_stop_words(words):
    words_filtered = []
    for word in words:
        if word not in stop_words:
            words_filtered.append(word)
    return words_filtered

# %%
stop_words.update(df_idf[df_idf['idf_weights']<5].index)
stop_words.update(['may', 'non', 'v', 'l', 'e', 'g', 'rw', 'r', 'xr', 'x', 'rwxr', 'still', 'much', 'c', 'p', 'n', 'k', 'b', 'h', 'f',
                   'lot', 'us', 'kind', 'q', 'w', 'z', 'en', 'ax', 'j', 'python', 'code', 'using', 'need', 'get', 'py', 'u', 'keep', 
                   'also', 'really', 'able', 'maybe', 'things', 'everything', 'happens', 'actually', 'lst', 'already',
                  'within', 'li', 'python', 'based', 'user', 'np', 'pd', 'tf', 'id', 'work', 'write', 'df', 'np', 'pd', 'make',
                  'said', 'gets', 'en', 'thus', 'dataframe', 'pandas', 'numpy', 'django', 'html', 'string', 'variable', 'javascript',
                   'function', 'class', 'file', 'unicode', 'index', 'column', 'row', 'list', 'array','set', 'argument', 'method',
                   'parameter', 'loop', 'array', 'key', 'value', 'element', 'return', 'xml', 'tkinter', 'dict', 'dictionary', 'character',
                   'byte', 'regex', 'hello', 'stackoverflow', 'tuple', 'module', 'tensorflow', 'json'])
data['ans_tokenized'] = data['ans_tokenized'].apply(filter_stop_words)

# %%
data
# Out:
#              id                                               tags  \
# 0      62766758  [python, pandas, shell, numpy, google, cloud, ...
# 1      62766758  [python, pandas, shell, numpy, google, cloud, ...
# 2      62742938                      [python, modulenotfounderror]
# 3      62741826       [python, pandas, performance, data, science]
# 4      62741826       [python, pandas, performance, data, science]
# ...         ...                                                ...
# 99995  35898687  [python, apache, spark, pyspark, apache, spark...
# 99996  35898687  [python, apache, spark, pyspark, apache, spark...
# 99997  35937882         [python, python, user, interface, tkinter]
# 99998  35937882         [python, python, user, interface, tkinter]
# 99999  35733050  [python, xml, virtual, reality, nuke, adobe, p...
#
#                                                  answers  \
# 0      <p>Container-Optimized OS (COS) has several li...
# 1      <p>I'm pretty sure that in case of Python libr...
# 2      <p>The standard library has a module <a href="...
# 3      <p>Hello and welcome to StackOverflow.</p>\r\n...
# 4      <p>I guess you want to <code>groupby</code> an...
# ...                                                  ...
# 99995  <p>Just for fun non-UDF solution:</p>\r\n\r\n<...
# 99996  <p>The following code does the requested task....
# 99997  <p>At the end of your code, just add <code>win...
# 99998  <p>You didn't do a </p>\r\n\r\n<pre><code>wind...
# 99999  <p>Whenever faced with a complex XML, consider...
#
#                                                     text  \
# 0      Container-Optimized OS (COS) has several limit...
# 1      I'm pretty sure that in case of Python librari...
# 2      The standard library has a module runpy for th...
# 3      Hello and welcome to StackOverflow.In pandas t...
# 4      I guess you want to groupby and exclude all th...
# ...                                                  ...
# 99995  Just for fun non-UDF solution:So it just:unrol...
# 99996  The following code does the requested task. An...
# 99997  At the end of your code, just add window.mainl...
# 99998  You didn't do a at the end. Check the Tkinter ...
# 99999  Whenever faced with a complex XML, consider an...
#
#                                                     link  \
# 0      https://cloud.google.com/container-optimized-o...
# 1
# 2           https://docs.python.org/3/library/runpy.html
# 3
# 4
# ...                                                  ...
# 99995
# 99996
# 99997
# 99998     https://docs.python.org/2/library/tkinter.html
# 99999         https://www.w3.org/TR/xslt http://lxml.de/
#
#                                                     code  \
# 0
# 1      failed to map segment from shared object\n.so\...
# 2      runpy\nimport runpy\r\nrunpy.run_module("my_pa...
# 3      groupby\nS\nIn [37]: def my_func(df): \r\n    ...
# 4      groupby\nmixid2\nset_index\nreset_index\ndf = ...
# ...                                                  ...
# 99995  from pyspark.sql.functions import col, first, ...
# 99996  DataFrame\n# Imports\r\nfrom pyspark.sql.types...
# 99997                                  window.mainloop()
# 99998                             window.mainloop() \r\n
# 99999  <xsl:transform xmlns:xsl="http://www.w3.org/19...
#
#                                            ans_tokenized
# 0      [container, optimized, os, cos, several, limit...
# 1      [pretty, libraries, natives, message, failed, ...
# 2      [standard, runpy, purpose, contain, justand, b...
# 3      [welcome, rule, thumb, raw, loops, slower, ded...
# 4      [guess, groupby, exclude, appears, times, shap...
# ...                                                  ...
# 99995  [fun, udataframe, unrolls, checks, item, col, ...
# 99996  [requested, task, receives, search, item, item...
# 99997      [window, mainloop, tells, form, ready, shown]
# 99998                                                 []
# 99999  [whenever, faced, complex, consider, xslt, tra...
#
# [100000 rows x 7 columns]

# %% [markdown]
# Some of the words are not useful, which are therefore added to the list of 'stop_words' and the answer text is filtered.

# %%
answers = data['ans_tokenized']

# %%
answers
# Out:
# 0        [container, optimized, os, cos, several, limit...
# 1        [pretty, libraries, natives, message, failed, ...
# 2        [standard, runpy, purpose, contain, justand, b...
# 3        [welcome, rule, thumb, raw, loops, slower, ded...
# 4        [guess, groupby, exclude, appears, times, shap...
#                                ...
# 99995    [fun, udataframe, unrolls, checks, item, col, ...
# 99996    [requested, task, receives, search, item, item...
# 99997        [window, mainloop, tells, form, ready, shown]
# 99998                                                   []
# 99999    [whenever, faced, complex, consider, xslt, tra...
# Name: ans_tokenized, Length: 100000, dtype: object

# %% [markdown]
# # Building the model

# %%
#Create dictionary and corpus
id2word = corpora.Dictionary(answers)
corpus = [id2word.doc2bow(answer) for answer in answers]

# %%
id2word

# %%
#Building an lda model
ldamodel = LdaMulticore(corpus=corpus, num_topics=8, id2word=id2word, passes=5)

# %%
pprint(ldamodel.show_topics(formatted=False))
# Out:
# [(0,
#   [('use', 0.015814284),
#    ('https', 0.011907165),
#    ('run', 0.010435523),
#    ('com', 0.010060439),
#    ('module', 0.007033758),
#    ('org', 0.0069094584),
#    ('script', 0.0067282463),
#    ('http', 0.00661805),
#    ('docs', 0.0065573794),
#    ('library', 0.006361261)]),
#  (1,
#   [('install', 0.011174302),
#    ('problem', 0.0111577455),
#    ('solution', 0.010875104),
#    ('version', 0.01037576),
#    ('pip', 0.009208534),
#    ('time', 0.008732329),
#    ('one', 0.007451768),
#    ('use', 0.0072588976),
#    ('answer', 0.0070147403),
#    ('way', 0.0066410326)]),
#  (2,
#   [('data', 0.01665481),
#    ('use', 0.015775694),
#    ('json', 0.009736119),
#    ('string', 0.0090228785),
#    ('like', 0.008553126),
#    ('one', 0.008488019),
#    ('exception', 0.006518087),
#    ('want', 0.006326511),
#    ('unicode', 0.005847602),
#    ('encoding', 0.005732725)]),
#  (3,
#   [('file', 0.052895606),
#    ('path', 0.014456955),
#    ('use', 0.013971603),
#    ('files', 0.01345255),
#    ('like', 0.0111537995),
#    ('directory', 0.009650848),
#    ('line', 0.009329095),
#    ('read', 0.008337841),
#    ('open', 0.0068716435),
#    ('want', 0.0066390526)]),
#  (4,
#   [('use', 0.030962497),
#    ('string', 0.016758928),
#    ('column', 0.013663098),
#    ('like', 0.012195499),
#    ('want', 0.012140411),
#    ('dataframe', 0.011671303),
#    ('index', 0.011012005),
#    ('values', 0.010568962),
#    ('first', 0.010550113),
#    ('try', 0.010165663)]),
#  (5,
#   [('list', 0.040617485),
#    ('loop', 0.019742481),
#    ('use', 0.015135208),
#    ('output', 0.014722433),
#    ('line', 0.011197086),
#    ('string', 0.010926978),
#    ('first', 0.010372691),
#    ('want', 0.010071821),
#    ('print', 0.009998996),
#    ('one', 0.009808466)]),
#  (6,
#   [('use', 0.015700266),
#    ('array', 0.011570245),
#    ('data', 0.010448674),
#    ('list', 0.010050148),
#    ('values', 0.008740587),
#    ('numpy', 0.0083918795),
#    ('value', 0.007766758),
#    ('function', 0.0076373406),
#    ('would', 0.0074677323),
#    ('number', 0.0070883534)]),
#  (7,
#   [('function', 0.019767031),
#    ('use', 0.017068384),
#    ('class', 0.014877984),
#    ('method', 0.011179659),
#    ('like', 0.011059584),
#    ('call', 0.0086635),
#    ('want', 0.007984953),
#    ('object', 0.007858376),
#    ('would', 0.007025526),
#    ('example', 0.0063649085)])]

# %%
ldamodel.log_perplexity(corpus)
# Out:
# -8.00664321231073

# %%
coherence_lda = CoherenceModel(model=ldamodel, texts=answers, dictionary=id2word, coherence='c_v')
score = coherence_lda.get_coherence()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-276-773283ced698> in <module>
# ----> 1 coherence_lda = CoherenceModel(model=ldamodel, texts=answers, dictionary=id2word, coherence='c_v')
#       2 score = coherence_lda.get_coherence()
#
# NameError: name 'ldamodel' is not defined

# %%
print("Coherence score of lda model: ",score)
# Out:
# Coherence score of lda model:  0.5431674009189242

# %%
ldamallet_model = LdaMallet(mallet_path, corpus=corpus, num_topics=8, id2word=id2word, alpha = 1, random_seed = 121)

# %%
pprint(ldamallet_model.show_topics(formatted=False))
# Out:
# [(0,
#   [('server', 0.01692325500636648),
#    ('request', 0.015649959486051628),
#    ('app', 0.011297603889339043),
#    ('url', 0.011152911216575993),
#    ('page', 0.010701470077555272),
#    ('client', 0.008490566037735849),
#    ('requests', 0.008397962727167496),
#    ('google', 0.00722305822433152),
#    ('post', 0.007020488482463248),
#    ('web', 0.006742678550758189)]),
#  (1,
#   [('csv', 0.012692436724195772),
#    ('table', 0.010990171593295312),
#    ('field', 0.010269504603571029),
#    ('query', 0.00995265963395087),
#    ('database', 0.00927548116946857),
#    ('encoding', 0.007778233371851741),
#    ('fields', 0.006448727028739703),
#    ('parse', 0.005870950907667648),
#    ('tag', 0.0057342726854785605),
#    ('form', 0.005721847392552279)]),
#  (2,
#   [('plot', 0.01301885737562199),
#    ('window', 0.010926255760644713),
#    ('button', 0.00770748304753081),
#    ('frame', 0.007675534931271615),
#    ('matplotlibrary', 0.007076507751411707),
#    ('widget', 0.007012611518893317),
#    ('size', 0.0060461810020526665),
#    ('color', 0.005694751723201521),
#    ('position', 0.00537527056060957),
#    ('pygame', 0.00524747809557279)]),
#  (3,
#   [('matrix', 0.0077523915396542145),
#    ('datetime', 0.0073252786472808125),
#    ('series', 0.007097095047245707),
#    ('date', 0.0068630605856712405),
#    ('float', 0.006786999385659538),
#    ('shape', 0.0065705175087031565),
#    ('random', 0.006043939970160606),
#    ('sum', 0.005967878770148904),
#    ('integer', 0.005815756370125501),
#    ('scipy', 0.004867916800748911)]),
#  (4,
#   [('memory', 0.010060104863804936),
#    ('faster', 0.005413700498742487),
#    ('performance', 0.004973215681259502),
#    ('language', 0.004887960555295054),
#    ('implementation', 0.004390638987169104),
#    ('large', 0.0036612340205843764),
#    ('speed', 0.003395995850917203),
#    ('algorithm', 0.003324949912613496),
#    ('pretty', 0.003301267933178927),
#    ('small', 0.003287058745518185)]),
#  (5,
#   [('match', 0.010660327906288763),
#    ('comprehension', 0.00976245218682043),
#    ('item', 0.009544470798278986),
#    ('items', 0.009124078120377627),
#    ('expression', 0.008989137260804352),
#    ('split', 0.00888014656653363),
#    ('word', 0.008272912698453889),
#    ('iterate', 0.0074580775079537255),
#    ('empty', 0.007307566549198919),
#    ('group', 0.006876793805176539)]),
#  (6,
#   [('exception', 0.009899256759982811),
#    ('thread', 0.009665833771001438),
#    ('global', 0.00745362044360978),
#    ('attribute', 0.00706104541668656),
#    ('main', 0.005734778433837845),
#    ('queue', 0.004992068923442564),
#    ('block', 0.00498676385551117),
#    ('foo', 0.004875357428951878),
#    ('threads', 0.004482782402028658),
#    ('event', 0.004010631356134516)]),
#  (7,
#   [('pip', 0.015169899249654407),
#    ('windows', 0.013829780812160066),
#    ('environment', 0.012658686321737084),
#    ('os', 0.011306494745166217),
#    ('packages', 0.009948266599057088),
#    ('folder', 0.00977924265198573),
#    ('project', 0.007829430691126847),
#    ('shell', 0.006573824227168185),
#    ('github', 0.0061512643594897895),
#    ('setup', 0.006012423260109745)])]

# %%
coherence_ldamallet = CoherenceModel(model=ldamallet_model, texts=answers, dictionary=id2word, coherence='c_v')
score = coherence_ldamallet.get_coherence()

# %%
print("Coherence score of lda mallet model: ",score)
# Out:
# Coherence score of lda mallet model:  0.5263612547016521

# %% [markdown]
# By comparing the scores, it is clearly evident that LDA Mallet model works better that LDA multicore model. We can use LDA mallet model and find optimal number of topics.

# %% [markdown]
# # Finding optimal number of topics

# %%
def coh_value(id2word, corpus, answers, start, stop, step):
    coh_values_list = []
    model_list = []
    for num_topics in range(start, stop, step):
        model = LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=id2word, alpha = 1, random_seed=11)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=answers, dictionary=id2word, coherence='c_v')
        coh_values_list.append(coherencemodel.get_coherence())
        print(num_topics)
    return model_list, coh_values_list

# %%
start = 2
stop = 20
step = 3

# %%
model_list, coh_values_list = coh_value(id2word, corpus, answers, start, stop, step)
# Out:
# 2
# 5
# 8
# 11
# 14
# 17

# %%
topic_num = range(start, stop, step)
plt.plot(topic_num, coh_values_list)
plt.title("Coherence value score for the number of topics")
plt.xlabel("No. of Topics")
plt.ylabel("Coherence score")
#plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
for i in range(start, stop, step):
    print("No. of topics:  ", i, ", Coherence Value: ", coh_values_list[(i-start)//3])
# Out:
# No. of topics:   2 , Coherence Value:  0.2136187901023405
# No. of topics:   5 , Coherence Value:  0.4723783990208732
# No. of topics:   8 , Coherence Value:  0.5414492003912681
# No. of topics:   11 , Coherence Value:  0.5856094200409331
# No. of topics:   14 , Coherence Value:  0.6009304937062198
# No. of topics:   17 , Coherence Value:  0.631654452929848

# %%
final_model = model_list[2]
model_topics = final_model.show_topics(formatted=False)
pprint(final_model.print_topics(num_words=10))
# Out:
# [(0,
#   '0.009*"attribute" + 0.009*"exception" + 0.007*"global" + 0.005*"foo" + '
#   '0.005*"attributes" + 0.005*"copy" + 0.004*"false" + 0.004*"scope" + '
#   '0.004*"keyword" + 0.004*"local"'),
#  (1,
#   '0.009*"memory" + 0.008*"database" + 0.007*"query" + 0.007*"table" + '
#   '0.005*"language" + 0.005*"sql" + 0.004*"performance" + 0.003*"faster" + '
#   '0.003*"easy" + 0.003*"large"'),
#  (2,
#   '0.015*"pip" + 0.013*"environment" + 0.013*"windows" + 0.011*"os" + '
#   '0.010*"packages" + 0.010*"folder" + 0.008*"project" + 0.006*"setup" + '
#   '0.006*"shell" + 0.006*"github"'),
#  (3,
#   '0.014*"match" + 0.012*"csv" + 0.012*"word" + 0.011*"split" + '
#   '0.009*"encoding" + 0.008*"words" + 0.007*"expression" + 0.007*"regular" + '
#   '0.006*"matches" + 0.006*"pattern"'),
#  (4,
#   '0.016*"request" + 0.015*"server" + 0.012*"page" + 0.012*"url" + 0.011*"app" '
#   '+ 0.010*"form" + 0.009*"template" + 0.008*"requests" + 0.008*"view" + '
#   '0.008*"post"'),
#  (5,
#   '0.010*"plot" + 0.008*"matrix" + 0.007*"size" + 0.007*"shape" + 0.006*"axis" '
#   '+ 0.005*"graph" + 0.005*"scipy" + 0.005*"matplotlibrary" + 0.004*"layer" + '
#   '0.004*"labels"'),
#  (6,
#   '0.012*"thread" + 0.009*"event" + 0.008*"window" + 0.007*"main" + '
#   '0.006*"queue" + 0.006*"button" + 0.006*"widget" + 0.006*"threads" + '
#   '0.006*"task" + 0.005*"message"'),
#  (7,
#   '0.009*"comprehension" + 0.008*"items" + 0.008*"item" + 0.008*"range" + '
#   '0.007*"series" + 0.007*"sort" + 0.007*"datetime" + 0.007*"generator" + '
#   '0.007*"date" + 0.006*"integer"')]

# %% [markdown]
# # Creating answer dataset with topics

# %%
topics = final_model[corpus]

# %%
topics
# Out:
# [[(0, 0.02242063492063492),
#   (1, 0.21924603174603174),
#   (2, 0.6557539682539683),
#   (3, 0.003373015873015873),
#   (4, 0.003373015873015873),
#   (5, 0.08273809523809524),
#   (6, 0.0017857142857142857),
#   (7, 0.01130952380952381)],
#  [(0, 0.004807692307692309),
#   (1, 0.06463675213675216),
#   (2, 0.7056623931623933),
#   (3, 0.1030982905982906),
#   (4, 0.004807692307692309),
#   (5, 0.06891025641025643),
#   (6, 0.0389957264957265),
#   (7, 0.009081196581196584)],
#  [(0, 0.5993589743589745),
#   (1, 0.009615384615384618),
#   (2, 0.31730769230769235),
#   (3, 0.009615384615384618),
#   (4, 0.018162393162393167),
#   (5, 0.009615384615384618),
#   (6, 0.02670940170940171),
#   (7, 0.009615384615384618)],
#  [(0, 0.4628136200716846),
#   (1, 0.011200716845878136),
#   (2, 0.004032258064516129),
#   (3, 0.04704301075268817),
#   (4, 0.0076164874551971325),
#   (5, 0.004032258064516129),
#   (6, 0.0076164874551971325),
#   (7, 0.45564516129032256)],
#  [(0, 0.015625),
#   (1, 0.029513888888888888),
#   (2, 0.015625),
#   (3, 0.08506944444444445),
#   (4, 0.057291666666666664),
#   (5, 0.09895833333333333),
#   (6, 0.043402777777777776),
#   (7, 0.6545138888888888)],
#  [(0, 0.1743827160493827),
#   (1, 0.05092592592592592),
#   (2, 0.038580246913580245),
#   (3, 0.013888888888888888),
#   (4, 0.026234567901234566),
#   (5, 0.026234567901234566),
#   (6, 0.026234567901234566),
#   (7, 0.6435185185185185)],
#  [(0, 0.125),
#   (1, 0.125),
#   (2, 0.125),
#   (3, 0.125),
#   (4, 0.125),
#   (5, 0.125),
#   (6, 0.125),
#   (7, 0.125)],
#  [(0, 0.009081196581196584),
#   (1, 0.22702991452991458),
#   (2, 0.34241452991453),
#   (3, 0.2056623931623932),
#   (3, 0.038580246913580245),
#   (4, 0.026234567901234566),
#   (5, 0.013888888888888888),
#   (6, 0.026234567901234566),
#   (7, 0.7916666666666666)],
#  [(0, 0.005681818181818182),
#   (1, 0.5107323232323232),
#   (2, 0.015782828282828284),
#   (3, 0.15214646464646464),
#   (4, 0.046085858585858584),
#   (5, 0.020833333333333332),
#   (6, 0.010732323232323232),
#   (7, 0.2380050505050505)],
#  [(0, 0.125),
#   (1, 0.125),
#   (2, 0.125),
#   (3, 0.125),
#   (4, 0.125),
#   (5, 0.125),
#   (6, 0.125),
#   (7, 0.125)],
#  [(0, 0.125),
#   (1, 0.125),
#   (2, 0.125),
#   (3, 0.125),
#   (4, 0.125),
#   (5, 0.125),
#   (6, 0.125),
#   (7, 0.125)],
#  [(0, 0.03503316749585406),
#   (1, 0.008499170812603648),
#   (2, 0.0018656716417910447),
#   (3, 0.9272388059701493),
#   (4, 0.0018656716417910447),
#   (5, 0.005182421227197346),
#   (6, 0.016791044776119403),
#   (7, 0.0035240464344941957)],
#  [(0, 0.011805555555555555),
#   (1, 0.050694444444444445),
#   (2, 0.00625),
#   (3, 0.6229166666666667),
#   (4, 0.017361111111111112),
#   (5, 0.1840277777777778),
#   (6, 0.00625),
#   (7, 0.10069444444444445)],
#  [(0, 0.10138888888888892),
#   (1, 0.023611111111111117),
#   (2, 0.012500000000000004),
#   (3, 0.8125000000000002),
#   (4, 0.012500000000000004),
#   (5, 0.012500000000000004),
#   (6, 0.012500000000000004),
#   (7, 0.012500000000000004)],
#  [(0, 0.06944444444444445),
#   (1, 0.18055555555555555),
#   (2, 0.025),
#   (3, 0.2916666666666667),
#   (4, 0.025),
#   (5, 0.2916666666666667),
#   (6, 0.025),
#   (7, 0.09166666666666666)],
#  [(0, 0.043402777777777776),
#   (1, 0.09895833333333333),
#   (2, 0.015625),
#   (3, 0.029513888888888888),
#   (4, 0.029513888888888888),
#   (5, 0.7378472222222222),
#   (6, 0.029513888888888888),
#   (7, 0.015625)],
#  [(0, 0.375),
#   (1, 0.041666666666666664),
#   (2, 0.11574074074074074),
#   (3, 0.0787037037037037),
#   (4, 0.18981481481481483),
#   (5, 0.041666666666666664),
#   (6, 0.041666666666666664),
#   (7, 0.11574074074074074)],
#  [(0, 0.06547619047619048),
#   (1, 0.14484126984126985),
#   (2, 0.017857142857142856),
#   (3, 0.06547619047619048),
#   (4, 0.03373015873015873),
#   (5, 0.017857142857142856),
#   (6, 0.017857142857142856),
#   (7, 0.6369047619047619)],
#  [(0, 0.06018518518518518),
#   (1, 0.05277777777777778),
#   (2, 0.01574074074074074),
#   (3, 0.41574074074074074),
#   (4, 0.008333333333333333),
#   (5, 0.42314814814814816),
#   (6, 0.008333333333333333),
#   (7, 0.01574074074074074)],
#  [(0, 0.02042483660130719),
#   (1, 0.03349673202614379),
#   (2, 0.007352941176470588),
#   (3, 0.22303921568627452),
#   (4, 0.007352941176470588),
#   (5, 0.013888888888888888),
#   (6, 0.5106209150326797),
#   (7, 0.18382352941176472)],
#  [(0, 0.5601851851851853),
#   (1, 0.04166666666666667),
#   (3, 0.01388888888888889),
#   (4, 0.05092592592592593),
#   (5, 0.08796296296296298),
#   (6, 0.02623456790123457),
#   (7, 0.03858024691358025)],
#  [(0, 0.6558641975308643),
#   (1, 0.02623456790123457),
#   (2, 0.05092592592592593),
#   (3, 0.03858024691358025),
#   (4, 0.03858024691358025),
#   (5, 0.14969135802469138),
#   (6, 0.01388888888888889),
#   (7, 0.02623456790123457)],
#  [(0, 0.04166666666666667),
#   (1, 0.04166666666666667),
#   (2, 0.04166666666666667),
#   (3, 0.6712962962962964),
#   (4, 0.07870370370370372),
#   (5, 0.04166666666666667),
#   (6, 0.04166666666666667),
#   (7, 0.04166666666666667)],
#  [(0, 0.8893229166666666),
#   (1, 0.00390625),
#   (2, 0.00390625),
#   (3, 0.00390625),
#   (4, 0.00390625),
#   (5, 0.00390625),
#   (6, 0.00390625),
#   (7, 0.08723958333333333)],
#  [(0, 0.125),
#   (1, 0.125),
#   (2, 0.125),
#   (3, 0.125),
#   (4, 0.125),
#   (5, 0.125),
#   (6, 0.125),
#   (7, 0.125)],
#  [(0, 0.4321895424836602),
#   (1, 0.020424836601307193),
#   (2, 0.007352941176470589),
#   (3, 0.22957516339869283),
#   (4, 0.007352941176470589),
#   (5, 0.01388888888888889),
#   (6, 0.28186274509803927),
#   (7, 0.007352941176470589)],
#  [(0, 0.3090277777777778),
#   (1, 0.03125),
#   (2, 0.03125),
#   (3, 0.11458333333333333),
#   (4, 0.059027777777777776),
#   (5, 0.03125),
#   (6, 0.03125),
#   (7, 0.3923611111111111)],
#  [(0, 0.059027777777777776),
#   (1, 0.03125),
#   (2, 0.059027777777777776),
#   (3, 0.6423611111111112),
#   (4, 0.03125),
#   (5, 0.03125),
#   (6, 0.03125),
#   (7, 0.11458333333333333)],
#  [(0, 0.025000000000000005),
#   (1, 0.04722222222222223),
#   (2, 0.025000000000000005),
#   (3, 0.7583333333333334),
#   (4, 0.04722222222222223),
#   (5, 0.025000000000000005),
#   (6, 0.04722222222222223),
#   (7, 0.025000000000000005)],
#  [(0, 0.1736111111111111),
#   (1, 0.1736111111111111),
#   (2, 0.0625),
#   (3, 0.0625),
#   (4, 0.11805555555555555),
#   (5, 0.1736111111111111),
#   (6, 0.1736111111111111),
#   (7, 0.0625)],
#  [(0, 0.4172077922077922),
#   (1, 0.10407647907647907),
#   (2, 0.02904040404040404),
#   (3, 0.007395382395382395),
#   (4, 0.0016233766233766235),
#   (5, 0.004509379509379509),
#   (6, 0.013167388167388168),
#   (7, 0.42297979797979796)],
#  [(0, 0.5518162393162395),
#   (1, 0.13728632478632483),
#   (2, 0.013354700854700856),
#   (3, 0.16720085470085472),
#   (4, 0.01762820512820513),
#   (5, 0.0389957264957265),
#   (6, 0.013354700854700856),
#   (7, 0.06036324786324787)],
#  [(0, 0.015625),
#   (1, 0.015625),
#   (2, 0.015625),
#   (3, 0.1545138888888889),
#   (4, 0.015625),
#   (5, 0.057291666666666664),
#   (6, 0.6961805555555556),
#   (7, 0.029513888888888888)],
#  [(0, 0.03125),
#   (1, 0.03125),
#   (2, 0.03125),
#   (1, 0.125),
#   (2, 0.125),
#   (3, 0.125),
#   (4, 0.125),
#   (5, 0.125),
#   (6, 0.125),
#   (7, 0.125)],
#  [(0, 0.013117283950617285),
#   (1, 0.006944444444444445),
#   (2, 0.006944444444444445),
#   (3, 0.9390432098765433),
#   (4, 0.006944444444444445),
#   (5, 0.006944444444444445),
#   (6, 0.013117283950617285),
#   (7, 0.006944444444444445)],
#  [(0, 0.04166666666666667),
#   (1, 0.04166666666666667),
#   (2, 0.04166666666666667),
#   (3, 0.7083333333333335),
#   (4, 0.04166666666666667),
#   (5, 0.04166666666666667),
#   (6, 0.04166666666666667),
#   (7, 0.04166666666666667)],
#  [(0, 0.11458333333333333),
#   (1, 0.08680555555555555),
#   (2, 0.03125),
#   (3, 0.03125),
#   (4, 0.1423611111111111),
#   (5, 0.03125),
#   (6, 0.059027777777777776),
#   (7, 0.5034722222222222)],
#  [(0, 0.014756944444444444),
#   (1, 0.17447916666666666),
#   (2, 0.014756944444444444),
#   (3, 0.035590277777777776),
#   (4, 0.049479166666666664),
#   (5, 0.15364583333333334),
#   (6, 0.014756944444444444),
#   (7, 0.5425347222222222)],
#  [(0, 0.011363636363636366),
#   (1, 0.011363636363636366),
#   (2, 0.011363636363636366),
#   (3, 0.011363636363636366),
#   (4, 0.1628787878787879),
#   (5, 0.051767676767676775),
#   (6, 0.7285353535353536),
#   (7, 0.011363636363636366)],
#  [(0, 0.7534722222222222),
#   (1, 0.03125),
#   (2, 0.03125),
#   (3, 0.03125),
#   (4, 0.03125),
#   (5, 0.03125),
#   (6, 0.059027777777777776),
#   (7, 0.03125)],
#  [(0, 0.38055555555555554),
#   (1, 0.025),
#   (2, 0.15833333333333333),
#   (3, 0.11388888888888889),
#   (4, 0.06944444444444445),
#   (5, 0.06944444444444445),
#   (6, 0.11388888888888889),
#   (7, 0.06944444444444445)],
#  [(0, 0.03525641025641026),
#   (1, 0.03525641025641026),
#   (2, 0.009615384615384618),
#   (3, 0.009615384615384618),
#   (4, 0.4797008547008548),
#   (5, 0.009615384615384618),
#   (6, 0.41132478632478636),
#   (7, 0.009615384615384618)],
#  [(0, 0.46412037037037035),
#   (1, 0.010416666666666666),
#   (2, 0.010416666666666666),
#   (3, 0.028935185185185185),
#   (4, 0.010416666666666666),
#   (5, 0.010416666666666666),
#   (6, 0.010416666666666666),
#   (7, 0.4548611111111111)],
#  [(0, 0.1830808080808081),
#   (1, 0.011363636363636364),
#   (2, 0.011363636363636364),
#   (3, 0.021464646464646464),
#   (4, 0.03156565656565657),
#   (5, 0.021464646464646464),
#   (6, 0.011363636363636364),
#   (7, 0.7083333333333334)],
#  [(0, 0.35833333333333334),
#   (1, 0.025),
#   (2, 0.04722222222222222),
#   (3, 0.04722222222222222),
#   (4, 0.09166666666666666),
#   (5, 0.025),
#   (6, 0.025),
#   (7, 0.38055555555555554)],
#  [(0, 0.3072916666666667),
#   (1, 0.015625),
#   (2, 0.015625),
#   (3, 0.015625),
#   (4, 0.015625),
#   (5, 0.015625),
#   (6, 0.5711805555555556),
#   (7, 0.043402777777777776)],
#   (5, 0.006944444444444444),
#   (6, 0.9205246913580247),
#   (7, 0.006944444444444444)],
#  [(0, 0.010416666666666666),
#   (1, 0.010416666666666666),
#   (2, 0.06597222222222222),
#   (3, 0.019675925925925927),
#   (4, 0.010416666666666666),
#   (5, 0.010416666666666666),
#   (6, 0.8530092592592593),
#   (7, 0.019675925925925927)],
#  [(0, 0.19791666666666666),
#   (1, 0.19791666666666666),
#   (2, 0.03125),
#   (3, 0.1701388888888889),
#   (4, 0.08680555555555555),
#   (5, 0.03125),
#   (6, 0.1701388888888889),
#   (7, 0.11458333333333333)],
#  [(0, 0.11388888888888889),
#   (1, 0.15833333333333333),
#   (2, 0.5805555555555556),
#   (3, 0.025),
#   (4, 0.04722222222222222),
#   (5, 0.025),
#   (6, 0.025),
#   (7, 0.025)],
#  [(0, 0.08958333333333333),
#   (1, 0.09513888888888888),
#   (2, 0.011805555555555555),
#   (3, 0.02847222222222222),
#   (4, 0.022916666666666665),
#   (5, 0.02847222222222222),
#   (6, 0.00625),
#   (7, 0.7173611111111111)],
#  [(0, 0.0078125),
#   (1, 0.0078125),
#   (2, 0.021701388888888888),
#   (3, 0.014756944444444444),
#   (4, 0.0078125),
#   (5, 0.014756944444444444),
#   (6, 0.1328125),
#   (7, 0.7925347222222222)],
#  [(0, 0.025),
#   (1, 0.025),
#   (2, 0.025),
#   (3, 0.025),
#   (4, 0.025),
#   (5, 0.025),
#   (6, 0.025),
#   (7, 0.825)],
#  [(0, 0.125),
#   (1, 0.125),
#   (2, 0.125),
#   (3, 0.125),
#   (4, 0.125),
#   (5, 0.125),
#   (6, 0.125),
#   (7, 0.125)],
#  [(0, 0.030884502923976608),
#   (1, 0.04696637426900585),
#   (2, 0.004568713450292397),
#   (3, 0.010416666666666666),
#   (4, 0.47094298245614036),
#   (5, 0.0031067251461988302),
#   (6, 0.1566154970760234),
#   (7, 0.2764985380116959)],
#  [(0, 0.019097222222222224),
#   (1, 0.17650462962962962),
#   (2, 0.005208333333333333),
#   (3, 0.3524305555555556),
#   (4, 0.43113425925925924),
#   (5, 0.005208333333333333),
#   (6, 0.005208333333333333),
#   (7, 0.005208333333333333)],
#  [(0, 0.125),
#   (1, 0.125),
#   (2, 0.125),
#   (3, 0.125),
#   (4, 0.125),
#   (5, 0.125),
#   (6, 0.125),
#   (7, 0.125)],
#  [(0, 0.03125),
#   (1, 0.78125),
#   (2, 0.03125),
#   (3, 0.03125),
#   (4, 0.03125),
#   (5, 0.03125),
#   (6, 0.03125),
#   (7, 0.03125)],
#  [(0, 0.041666666666666664),
#   (1, 0.041666666666666664),
#   (2, 0.041666666666666664),
#   (3, 0.041666666666666664),
#   (4, 0.0787037037037037),
#   (5, 0.375),
#   (6, 0.041666666666666664),
#   (7, 0.33796296296296297)],
#  [(0, 0.05671296296296297),
#   (1, 0.02893518518518519),
#   (2, 0.3530092592592593),
#   (3, 0.13078703703703706),
#   (4, 0.39004629629629634),
#   (5, 0.010416666666666668),
#   (6, 0.01967592592592593),
#   (7, 0.010416666666666668)],
#  [(0, 0.0041423001949317745),
#   (1, 0.002192982456140351),
#   (2, 0.2887426900584796),
#   (3, 0.002192982456140351),
#   (4, 0.6162280701754387),
#   (5, 0.008040935672514621),
#   (6, 0.07626705653021444),
#   (7, 0.002192982456140351)],
#  [(0, 0.013888888888888892),
#   (1, 0.03858024691358025),
#   (2, 0.026234567901234573),
#   (3, 0.11265432098765435),
#   (4, 0.742283950617284),
#   (5, 0.013888888888888892),
#   (6, 0.03858024691358025),
#   (7, 0.013888888888888892)],
#  [(0, 0.025),
#   (1, 0.025),
#   (2, 0.025),
#   (3, 0.025),
#   (4, 0.025),
#   (5, 0.09166666666666666),
#   (6, 0.025),
#   (7, 0.7583333333333333)],
#  [(0, 0.020833333333333332),
#   (1, 0.005681818181818182),
#   (2, 0.15214646464646464),
#   (3, 0.041035353535353536),
#   (4, 0.7481060606060606),
#   (5, 0.005681818181818182),
#   (6, 0.015782828282828284),
#   (7, 0.010732323232323232)],
#  [(0, 0.0625),
#   (1, 0.0625),
#   (2, 0.0625),
#   (3, 0.2847222222222222),
#   (4, 0.0625),
#   (5, 0.0625),
#   (6, 0.0625),
#   (7, 0.3402777777777778)],
#  [(0, 0.025),
#   (1, 0.025),
#   (2, 0.1361111111111111),
#   (3, 0.06944444444444445),
#   (4, 0.6694444444444444),
#   (5, 0.025),
#   (6, 0.025),
#   (7, 0.025)],
#  [(0, 0.029970760233918127),
#   (1, 0.035818713450292396),
#   (2, 0.3223684210526316),
#   (3, 0.012426900584795321),
#   (4, 0.5387426900584795),
#   (5, 0.02412280701754386),
#   (6, 0.02412280701754386),
#   (7, 0.012426900584795321)],
#  [(0, 0.011805555555555557),
#   (1, 0.12291666666666667),
#   (2, 0.595138888888889),
#   (3, 0.006250000000000001),
#   (4, 0.011805555555555557),
#   (5, 0.011805555555555557),
#   (6, 0.2340277777777778),
#   (7, 0.006250000000000001)],
#  [(0, 0.01697530864197531),
#   (1, 0.4284979423868313),
#   (2, 0.506687242798354),
#   (3, 0.008744855967078191),
#   (4, 0.00462962962962963),
#   (5, 0.008744855967078191),
#   (6, 0.021090534979423873),
#   (7, 0.00462962962962963)],
#  [(0, 0.028472222222222225),
#   (1, 0.08958333333333335),
#   (2, 0.845138888888889),
#   (3, 0.006250000000000001),
#   (4, 0.006250000000000001),
#   (5, 0.006250000000000001),
#   (6, 0.011805555555555557),
#   (7, 0.006250000000000001)],
#  [(0, 0.4201388888888889),
#   (1, 0.03125),
#   (2, 0.03125),
#   (3, 0.03125),
#   (4, 0.03125),
#   (5, 0.03125),
#   (6, 0.3923611111111111),
#   (7, 0.03125)],
#  [(0, 0.42669753086419754),
#   (1, 0.06867283950617284),
#   (2, 0.006944444444444444),
#   (3, 0.019290123456790122),
#   (4, 0.013117283950617283),
#   (5, 0.14891975308641975),
#   (6, 0.2970679012345679),
#   (7, 0.019290123456790122)],
#  [(0, 0.4583333333333334),
#   (1, 0.013888888888888892),
#   (2, 0.013888888888888892),
#   (3, 0.026234567901234573),
#   (4, 0.013888888888888892),
#   (5, 0.013888888888888892),
#   (6, 0.44598765432098775),
#   (3, 0.009837962962962965),
#   (4, 0.005208333333333334),
#   (5, 0.014467592592592594),
#   (6, 0.009837962962962965),
#   (7, 0.023726851851851857)],
#  [(0, 0.025),
#   (1, 0.025),
#   (2, 0.025),
#   (3, 0.8027777777777778),
#   (4, 0.025),
#   (5, 0.025),
#   (6, 0.04722222222222222),
#   (7, 0.025)],
#  [(0, 0.125),
#   (1, 0.125),
#   (2, 0.125),
#   (3, 0.125),
#   (4, 0.125),
#   (5, 0.125),
#   (6, 0.125),
#   (7, 0.125)],
#  [(0, 0.020833333333333332),
#   (1, 0.020833333333333332),
#   (2, 0.3541666666666667),
#   (3, 0.22453703703703703),
#   (4, 0.22453703703703703),
#   (5, 0.05787037037037037),
#   (6, 0.03935185185185185),
#   (7, 0.05787037037037037)],
#  [(0, 0.013888888888888892),
#   (1, 0.7669753086419755),
#   (2, 0.08796296296296298),
#   (3, 0.013888888888888892),
#   (4, 0.026234567901234573),
#   (5, 0.013888888888888892),
#   (6, 0.03858024691358025),
#   (7, 0.03858024691358025)],
#  [(0, 0.008333333333333333),
#   (1, 0.030555555555555555),
#   (2, 0.04537037037037037),
#   (3, 0.7564814814814815),
#   (4, 0.05277777777777778),
#   (5, 0.08981481481481482),
#   (6, 0.008333333333333333),
#   (7, 0.008333333333333333)],
#  [(0, 0.09027777777777778),
#   (1, 0.13472222222222222),
#   (2, 0.19027777777777777),
#   (3, 0.0125),
#   (4, 0.0125),
#   (5, 0.0125),
#   (6, 0.5347222222222222),
#   (7, 0.0125)],
#  [(0, 0.125),
#   (1, 0.125),
#   (2, 0.125),
#   (3, 0.125),
#   (4, 0.125),
#   (5, 0.125),
#   (6, 0.125),
#   (7, 0.125)],
#  [(0, 0.5949074074074073),
#   (1, 0.039351851851851846),
#   (2, 0.02083333333333333),
#   (3, 0.22453703703703698),
#   (4, 0.02083333333333333),
#   (5, 0.02083333333333333),
#   (6, 0.039351851851851846),
#   (7, 0.039351851851851846)],
#  [(0, 0.03125),
#   (1, 0.03125),
#   (2, 0.03125),
#   (3, 0.6423611111111112),
#   (4, 0.03125),
#   (5, 0.08680555555555555),
#   (6, 0.059027777777777776),
#   (7, 0.08680555555555555)],
#  [(0, 0.10503472222222222),
#   (1, 0.2092013888888889),
#   (2, 0.0078125),
#   (3, 0.2508680555555556),
#   (4, 0.3897569444444444),
#   (5, 0.0078125),
#   (6, 0.014756944444444444),
#   (7, 0.014756944444444444)],
#  [(0, 0.125),
#   (1, 0.125),
#   (2, 0.125),
#   (3, 0.125),
#   (4, 0.125),
#   (5, 0.125),
#   (6, 0.125),
#   (7, 0.125)],
#  [(0, 0.05964052287581701),
#   (1, 0.19035947712418305),
#   (2, 0.00735294117647059),
#   (3, 0.7001633986928105),
#   (4, 0.00735294117647059),
#   (5, 0.013888888888888892),
#   (6, 0.013888888888888892),
#   (7, 0.00735294117647059)],
#  [(0, 0.007352941176470588),
#   (1, 0.007352941176470588),
#   (2, 0.013888888888888888),
#   (3, 0.9158496732026143),
#   (4, 0.007352941176470588),
#   (5, 0.007352941176470588),
#   (6, 0.02042483660130719),
#   (7, 0.02042483660130719)],
#  [(0, 0.3402777777777778),
#   (1, 0.0625),
#   (2, 0.0625),
#   (3, 0.1736111111111111),
#   (4, 0.0625),
#   (5, 0.0625),
#   (6, 0.11805555555555555),
#   (7, 0.11805555555555555)],
#  [(0, 0.02546296296296296),
#   (1, 0.006944444444444444),
#   (2, 0.8649691358024691),
#   (3, 0.006944444444444444),
#   (4, 0.06867283950617284),
#   (5, 0.006944444444444444),
#   (6, 0.013117283950617283),
#   (7, 0.006944444444444444)],
#  [(0, 0.009615384615384616),
#   (1, 0.009615384615384616),
#   (2, 0.05235042735042735),
#   (3, 0.009615384615384616),
#   (4, 0.018162393162393164),
#   (5, 0.018162393162393164),
#   (6, 0.8728632478632479),
#   (7, 0.009615384615384616)],
#  [(0, 0.02146464646464646),
#   (1, 0.011363636363636362),
#   (2, 0.9002525252525251),
#   (3, 0.011363636363636362),
#   (4, 0.02146464646464646),
#   (5, 0.011363636363636362),
#   (6, 0.011363636363636362),
#   (7, 0.011363636363636362)],
#  [(0, 0.029513888888888888),
#   (1, 0.015625),
#   (2, 0.6684027777777778),
#   (3, 0.015625),
#   (4, 0.015625),
#   (5, 0.057291666666666664),
#   (6, 0.043402777777777776),
#   (7, 0.1545138888888889)],
#  [(0, 0.3138888888888889),
#   (1, 0.04722222222222222),
#   (2, 0.1361111111111111),
#   (3, 0.025),
#   (4, 0.025),
#   (5, 0.025),
#   (6, 0.4027777777777778),
#   (7, 0.025)],
#  [(0, 0.8569444444444446),
#   (1, 0.03472222222222223),
#   (2, 0.03472222222222223),
#   (3, 0.023611111111111117),
#   (4, 0.012500000000000004),
#   (5, 0.012500000000000004),
#   (6, 0.012500000000000004),
#   (7, 0.012500000000000004)],
#  [(0, 0.0625),
#   (1, 0.0625),
#   (2, 0.0625),
#   (3, 0.5625),
#   (4, 0.0625),
#   (5, 0.0625),
#   (6, 0.0625),
#   (7, 0.0625)],
#  [(0, 0.03125),
#   (1, 0.03125),
#   (2, 0.059027777777777776),
#   (3, 0.7256944444444444),
#   (4, 0.059027777777777776),
#   (5, 0.03125),
#   (6, 0.03125),
#   (7, 0.03125)],
#  [(0, 0.019675925925925927),
#   (1, 0.17708333333333334),
#   (2, 0.010416666666666666),
#   (3, 0.019675925925925927),
#   (4, 0.028935185185185185),
#   (5, 0.6678240740740741),
#   (6, 0.010416666666666666),
#   (7, 0.06597222222222222)],
#  [(0, 0.002777777777777778),
#   (1, 0.052160493827160495),
#   (2, 0.002777777777777778),
#   (3, 0.2101851851851852),
#   (4, 0.005246913580246914),
#   (5, 0.002777777777777778),
#   (6, 0.007716049382716049),
#   (7, 0.716358024691358)],
#  [(0, 0.03125),
#   (1, 0.03125),
#   (2, 0.1423611111111111),
#   (3, 0.03125),
#   (4, 0.22569444444444445),
#   (5, 0.03125),
#   (6, 0.4756944444444444),
#   (7, 0.03125)],
#  [(0, 0.0078125),
#   (1, 0.0842013888888889),
#   (2, 0.0078125),
#   (3, 0.014756944444444444),
#   (4, 0.3272569444444444),
#   (5, 0.1467013888888889),
#   (6, 0.4036458333333333),
#   (7, 0.0078125)],
#  [(0, 0.10667848699763595),
#   (1, 0.11849881796690309),
#   (2, 0.01211583924349882),
#   (3, 0.007387706855791963),
#   (4, 0.5156619385342791),
#   (5, 0.0050236406619385355),
#   (6, 0.23197399527186763),
#   (7, 0.0026595744680851068)],
#  [(0, 0.9175347222222222),
#   (1, 0.028645833333333332),
#   (2, 0.0078125),
#   (3, 0.0078125),
#   (4, 0.014756944444444444),
#   (5, 0.0078125),
#   (6, 0.0078125),
#   (7, 0.0078125)],
#  [(0, 0.1684027777777778),
#   (1, 0.07118055555555555),
#   (2, 0.015625),
#   (3, 0.11284722222222222),
#   (4, 0.015625),
#   (5, 0.043402777777777776),
#   (6, 0.015625),
#   (7, 0.5572916666666666)],
#  [(0, 0.42824074074074076),
#   (1, 0.020833333333333332),
#   (2, 0.020833333333333332),
#   (3, 0.020833333333333332),
#   (4, 0.020833333333333332),
#   (5, 0.020833333333333332),
#   (6, 0.16898148148148148),
#   (7, 0.2986111111111111)],
#  [(0, 0.10030864197530864),
#   (1, 0.013888888888888888),
#   (2, 0.013888888888888888),
#   (3, 0.026234567901234566),
#   (4, 0.013888888888888888),
#   (5, 0.1743827160493827),
#   (6, 0.6311728395061729),
#   (7, 0.026234567901234566)],
#  [(0, 0.015625000000000003),
#   (1, 0.02951388888888889),
#   (2, 0.04340277777777778),
#   (3, 0.8072916666666667),
#   (4, 0.02951388888888889),
#   (5, 0.015625000000000003),
#   (6, 0.015625000000000003),
#   (7, 0.04340277777777778)],
#  [(0, 0.03125),
#   (1, 0.03125),
#   (2, 0.3090277777777778),
#   (3, 0.4479166666666667),
#   (4, 0.03125),
#   (5, 0.03125),
#   (6, 0.03125),
#   (7, 0.08680555555555555)],
#  [(0, 0.041666666666666664),
#   (1, 0.11574074074074074),
#   (2, 0.041666666666666664),
#   (3, 0.041666666666666664),
#   (4, 0.041666666666666664),
#   (5, 0.041666666666666664),
#   (6, 0.041666666666666664),
#   (7, 0.6342592592592593)],
#  [(0, 0.0625),
#   (1, 0.0625),
#   (2, 0.0625),
#   (3, 0.2847222222222222),
#   (4, 0.3402777777777778),
#   (5, 0.0625),
#   (6, 0.0625),
#   (7, 0.0625)],
#  [(0, 0.019675925925925927),
#   (1, 0.09375),
#   (2, 0.010416666666666666),
#   (3, 0.028935185185185185),
# ...
#   (7, 0.020833333333333332)],
#  [(0, 0.008333333333333333),
#   (1, 0.023148148148148147),
#   (2, 0.008333333333333333),
#   (3, 0.008333333333333333),
#   (4, 0.01574074074074074),
#   (5, 0.023148148148148147),
#   (6, 0.008333333333333333),
#   (7, 0.9046296296296297)],
#  [(0, 0.06250000000000001),
#   (1, 0.06250000000000001),
#   (2, 0.06250000000000001),
#   (3, 0.39583333333333337),
#   (4, 0.06250000000000001),
#   (5, 0.06250000000000001),
#   (6, 0.06250000000000001),
#   (7, 0.22916666666666669)],
#  [(0, 0.0625),
#   (1, 0.0625),
#   (2, 0.0625),
#   (3, 0.1736111111111111),
#   (4, 0.0625),
#   (5, 0.0625),
#   (6, 0.0625),
#   (4, 0.4680555555555556),
#   (5, 0.012500000000000002),
#   (6, 0.023611111111111114),
#   (7, 0.012500000000000002)],
#  [(0, 0.09297839506172838),
#   (1, 0.00655864197530864),
#   (2, 0.00655864197530864),
#   (3, 0.73804012345679),
#   (4, 0.003472222222222221),
#   (5, 0.00655864197530864),
#   (6, 0.14236111111111108),
#   (7, 0.003472222222222221)],
#  [(0, 0.06944444444444445),
#   (1, 0.04722222222222222),
#   (2, 0.04722222222222222),
#   (3, 0.06944444444444445),
#   (4, 0.025),
#   (5, 0.025),
#   (6, 0.09166666666666666),
#   (7, 0.625)],
#  [(0, 0.125),
#   (1, 0.125),
#   (2, 0.125),
#   (3, 0.125),
#   (4, 0.125),
#   (5, 0.125),
#   (6, 0.125),
#   (7, 0.125)],
#  [(0, 0.7378472222222223),
#   (1, 0.02951388888888889),
#   (2, 0.02951388888888889),
#   (3, 0.015625000000000003),
#   (4, 0.015625000000000003),
#   (5, 0.05729166666666667),
#   (6, 0.015625000000000003),
#   (7, 0.09895833333333334)],
#  [(0, 0.8541666666666664),
#   (1, 0.02083333333333333),
#   (2, 0.02083333333333333),
#   (3, 0.02083333333333333),
#   (4, 0.02083333333333333),
#   (5, 0.02083333333333333),
#   (6, 0.02083333333333333),
#   (7, 0.02083333333333333)],
#  [(0, 0.11184210526315791),
#   (1, 0.08845029239766083),
#   (2, 0.287280701754386),
#   (3, 0.4451754385964913),
#   (4, 0.024122807017543862),
#   (5, 0.02997076023391813),
#   (6, 0.006578947368421053),
#   (7, 0.006578947368421053)],
#  [(0, 0.02083333333333333),
#   (1, 0.02083333333333333),
#   (2, 0.5949074074074073),
#   (3, 0.28009259259259256),
#   (4, 0.02083333333333333),
#   (5, 0.02083333333333333),
#   (6, 0.02083333333333333),
#   (7, 0.02083333333333333)],
#  [(0, 0.05277777777777779),
#   (1, 0.3787037037037038),
#   (2, 0.015740740740740743),
#   (3, 0.3564814814814815),
#   (4, 0.015740740740740743),
#   (5, 0.02314814814814815),
#   (6, 0.008333333333333335),
#   (7, 0.1490740740740741)],
#  [(0, 0.059027777777777776),
#   (1, 0.059027777777777776),
#   (2, 0.03125),
#   (3, 0.6979166666666666),
#   (4, 0.03125),
#   (5, 0.059027777777777776),
#   (6, 0.03125),
#   (7, 0.03125)],
#  [(0, 0.1280624568668047),
#   (1, 0.11080917874396136),
#   (2, 0.0017684610075914423),
#   (3, 0.01488095238095238),
#   (4, 0.002113526570048309),
#   (5, 0.022472394755003452),
#   (6, 0.6156400966183575),
#   (7, 0.10425293305728088)],
#  [(0, 0.2086226851851852),
#   (1, 0.002604166666666667),
#   (2, 0.002604166666666667),
#   (3, 0.2063078703703704),
#   (4, 0.002604166666666667),
#   (5, 0.0049189814814814825),
#   (6, 0.22945601851851855),
#   (7, 0.3428819444444445)],
#  [(0, 0.06759259259259259),
#   (1, 0.01574074074074074),
#   (2, 0.008333333333333333),
#   (3, 0.3712962962962963),
#   (4, 0.023148148148148147),
#   (5, 0.008333333333333333),
#   (6, 0.44537037037037036),
#   (7, 0.06018518518518518)],
#  [(0, 0.0248015873015873),
#   (1, 0.008928571428571428),
#   (2, 0.8660714285714286),
#   (3, 0.016865079365079364),
#   (4, 0.040674603174603176),
#   (5, 0.008928571428571428),
#   (6, 0.0248015873015873),
#   (7, 0.008928571428571428)],
#  [(0, 0.1517857142857143),
#   (1, 0.3025793650793651),
#   (2, 0.056547619047619055),
#   (3, 0.03273809523809525),
#   (4, 0.024801587301587304),
#   (5, 0.00892857142857143),
#   (6, 0.38988095238095244),
#   (7, 0.03273809523809525)],
#  [(0, 0.015740740740740743),
#   (1, 0.02314814814814815),
#   (2, 0.5490740740740742),
#   (3, 0.015740740740740743),
#   (4, 0.3564814814814815),
#   (5, 0.008333333333333335),
#   (6, 0.008333333333333335),
#   (7, 0.02314814814814815)],
#  [(0, 0.018333333333333333),
#   (1, 0.085),
#   (2, 0.005),
#   (3, 0.005),
#   (4, 0.5072222222222222),
#   (5, 0.009444444444444445),
#   (6, 0.365),
#   (7, 0.005)],
#  [(0, 0.336904761904762),
#   (1, 0.006746031746031747),
#   (2, 0.0035714285714285718),
#   (3, 0.013095238095238097),
#   (4, 0.40357142857142864),
#   (5, 0.0035714285714285718),
#   (6, 0.228968253968254),
#   (7, 0.0035714285714285718)],
#  [(0, 0.020833333333333332),
#   (1, 0.005681818181818182),
#   (2, 0.005681818181818182),
#   (3, 0.010732323232323232),
#   (4, 0.4147727272727273),
#   (5, 0.010732323232323232),
#   (6, 0.5258838383838383),
#   (7, 0.005681818181818182)],
#  [(0, 0.4756944444444444),
#   (1, 0.03125),
#   (2, 0.03125),
#   (3, 0.22569444444444445),
#   (4, 0.1423611111111111),
#   (5, 0.03125),
#   (6, 0.03125),
#   (7, 0.03125)],
#  [(0, 0.636059670781893),
#   (1, 0.004372427983539095),
#   (2, 0.04552469135802469),
#   (3, 0.11136831275720165),
#   (4, 0.1257716049382716),
#   (5, 0.016718106995884774),
#   (6, 0.008487654320987654),
#   (7, 0.05169753086419753)],
#  [(0, 0.05787037037037037),
#   (1, 0.03935185185185185),
#   (2, 0.020833333333333332),
#   (3, 0.7800925925925926),
#   (4, 0.020833333333333332),
#   (5, 0.03935185185185185),
#   (6, 0.020833333333333332),
#   (7, 0.020833333333333332)],
#  [(0, 0.025),
#   (1, 0.04722222222222222),
#   (2, 0.09166666666666666),
#   (3, 0.20277777777777778),
#   (4, 0.06944444444444445),
#   (5, 0.025),
#   (6, 0.025),
#   (7, 0.5138888888888888)],
#  [(0, 0.004310344827586207),
#   (1, 0.004310344827586207),
#   (2, 0.004310344827586207),
#   (3, 0.004310344827586207),
#   (4, 0.004310344827586207),
#   (5, 0.73227969348659),
#   (6, 0.004310344827586207),
#   (7, 0.2418582375478927)],
#  [(0, 0.011973180076628353),
#   (1, 0.004310344827586207),
#   (2, 0.004310344827586207),
#   (3, 0.019636015325670497),
#   (4, 0.05411877394636015),
#   (5, 0.008141762452107279),
#   (6, 0.004310344827586207),
#   (7, 0.8931992337164751)],
#  [(0, 0.020833333333333332),
#   (1, 0.020833333333333332),
#   (2, 0.020833333333333332),
#   (3, 0.020833333333333332),
#   (4, 0.020833333333333332),
#   (5, 0.020833333333333332),
#   (6, 0.020833333333333332),
#   (7, 0.8541666666666666)],
#  [(0, 0.017857142857142856),
#   (1, 0.06547619047619048),
#   (2, 0.017857142857142856),
#   (3, 0.7162698412698413),
#   (4, 0.03373015873015873),
#   (5, 0.017857142857142856),
#   (6, 0.08134920634920635),
#   (7, 0.0496031746031746)],
#  [(0, 0.005434782608695651),
#   (1, 0.8121980676328501),
#   (2, 0.005434782608695651),
#   (3, 0.010265700483091786),
#   (4, 0.1117149758454106),
#   (5, 0.024758454106280185),
#   (6, 0.010265700483091786),
#   (7, 0.019927536231884053)],
#  [(0, 0.013888888888888892),
#   (1, 0.013888888888888892),
#   (2, 0.7916666666666669),
#   (3, 0.026234567901234573),
#   (4, 0.013888888888888892),
#   (5, 0.03858024691358025),
#   (6, 0.08796296296296298),
#   (7, 0.013888888888888892)],
#  [(0, 0.021464646464646464),
#   (1, 0.021464646464646464),
#   (2, 0.041666666666666664),
#   (3, 0.05176767676767677),
#   (4, 0.011363636363636364),
#   (5, 0.021464646464646464),
#   (6, 0.021464646464646464),
#   (7, 0.8093434343434344)],
#  [(0, 0.6125000000000002),
#   (1, 0.04583333333333334),
#   (2, 0.24583333333333338),
#   (3, 0.012500000000000004),
#   (4, 0.012500000000000004),
#   (5, 0.012500000000000004),
#   (6, 0.012500000000000004),
#   (7, 0.04583333333333334)],
#  [(0, 0.005681818181818182),
#   (1, 0.005681818181818182),
#   (2, 0.005681818181818182),
#   (3, 0.005681818181818182),
#   (4, 0.9602272727272727),
#   (5, 0.005681818181818182),
#   (6, 0.005681818181818182),
#   (7, 0.005681818181818182)],
#  [(0, 0.023726851851851857),
#   (1, 0.22280092592592596),
#   (2, 0.005208333333333334),
#   (3, 0.019097222222222227),
#   (4, 0.6996527777777779),
#   (5, 0.009837962962962965),
#   (6, 0.009837962962962965),
#   (7, 0.009837962962962965)],
#  [(0, 0.02546296296296296),
#   (1, 0.22299382716049382),
#   (2, 0.031635802469135804),
#   (3, 0.006944444444444444),
#   (4, 0.006944444444444444),
#   (5, 0.019290123456790122),
#   (6, 0.6674382716049383),
#   (7, 0.019290123456790122)],
#  [(0, 0.003125),
#   (1, 0.058680555555555555),
#   (2, 0.019791666666666666),
#   (3, 0.003125),
#   (4, 0.15868055555555555),
#   (5, 0.01423611111111111),
#   (6, 0.7392361111111111),
#   (7, 0.003125)],
#  [(0, 0.03156565656565657),
#   (1, 0.06186868686868687),
#   (2, 0.011363636363636364),
#   (3, 0.03156565656565657),
#   (4, 0.021464646464646464),
#   (5, 0.7083333333333334),
#   (6, 0.03156565656565657),
#   (7, 0.10227272727272728)],
#  [(0, 0.04722222222222222),
#   (1, 0.26944444444444443),
#   (2, 0.06944444444444445),
#   (3, 0.025),
#   (4, 0.025),
#   (5, 0.46944444444444444),
#   (6, 0.025),
#   (7, 0.06944444444444445)],
#  [(0, 0.020622895622895626),
#   (1, 0.01388888888888889),
#   (2, 0.9263468013468015),
#   (3, 0.0037878787878787884),
#   (4, 0.01388888888888889),
#   (5, 0.0037878787878787884),
#   (6, 0.01388888888888889),
#   (7, 0.0037878787878787884)],
#  [(0, 0.04722222222222222),
#   (1, 0.025),
#   (2, 0.7805555555555556),
#   (3, 0.025),
#   (4, 0.025),
#   (5, 0.025),
#   (6, 0.025),
#   (7, 0.04722222222222222)],
#  [(0, 0.03125),
#   (1, 0.059027777777777776),
#   (2, 0.03125),
#   (3, 0.03125),
#   (4, 0.03125),
#   (5, 0.059027777777777776),
#   (6, 0.03125),
#   (7, 0.7256944444444444)],
#  [(0, 0.125),
#   (1, 0.125),
#   (2, 0.125),
#   (3, 0.125),
#   (4, 0.125),
#   (5, 0.125),
#   (6, 0.125),
#   (7, 0.125)],
#  [(0, 0.06547619047619048),
#   (1, 0.017857142857142856),
#   (2, 0.03373015873015873),
#   (3, 0.03373015873015873),
#   (4, 0.017857142857142856),
#   (5, 0.03373015873015873),
#   (6, 0.7797619047619048),
#   (7, 0.017857142857142856)],
#  [(0, 0.005589430894308943),
#   (1, 0.6465108401084011),
#   (2, 0.015074525745257453),
#   (3, 0.02184959349593496),
#   (4, 0.008299457994579946),
#   (5, 0.009654471544715448),
#   (6, 0.14244579945799457),
#   (7, 0.1505758807588076)],
#  [(0, 0.005434782608695652),
#   (1, 0.005434782608695652),
#   (2, 0.010265700483091788),
#   (3, 0.3532608695652174),
#   (4, 0.029589371980676328),
#   (5, 0.16485507246376813),
#   (6, 0.010265700483091788),
#   (7, 0.42089371980676327)],
#  [(0, 0.04166666666666667),
#   (1, 0.18981481481481488),
#   (2, 0.07870370370370372),
#   (3, 0.3750000000000001),
#   (4, 0.04166666666666667),
#   (5, 0.18981481481481488),
#   (6, 0.04166666666666667),
#   (7, 0.04166666666666667)],
#  [(0, 0.125),
#   (1, 0.125),
#   (2, 0.125),
#   (3, 0.125),
#   (4, 0.125),
#   (5, 0.125),
#   (6, 0.125),
#   (7, 0.125)],
#  [(0, 0.11574074074074074),
#   (1, 0.0787037037037037),
#   (2, 0.041666666666666664),
#   (3, 0.2638888888888889),
#   (4, 0.041666666666666664),
#   (5, 0.041666666666666664),
#   (6, 0.0787037037037037),
#   (7, 0.33796296296296297)],
#  [(0, 0.012366818873668192),
#   (1, 0.12652207001522073),
#   (2, 0.25894216133942166),
#   (3, 0.34265601217656017),
#   (4, 0.00780060882800609),
#   (5, 0.001712328767123288),
#   (6, 0.24219939117199396),
#   (7, 0.00780060882800609)],
#  [(0, 0.08207070707070706),
#   (1, 0.17297979797979796),
#   (2, 0.2941919191919191),
#   (3, 0.28409090909090906),
#   (4, 0.03156565656565656),
#   (5, 0.011363636363636362),
#   (6, 0.051767676767676754),
#   (7, 0.07196969696969696)],
#  [(0, 0.08093869731800768),
#   (1, 0.6020114942528737),
#   (2, 0.01580459770114943),
#   (3, 0.18055555555555558),
#   (4, 0.02729885057471265),
#   (5, 0.00814176245210728),
#   (6, 0.08093869731800768),
#   (7, 0.004310344827586208)],
#  [(0, 0.011363636363636364),
#   (1, 0.5568181818181818),
#   (2, 0.3143939393939394),
#   (3, 0.011363636363636364),
#   (4, 0.03156565656565657),
#   (5, 0.011363636363636364),
#   (6, 0.011363636363636364),
#   (7, 0.05176767676767677)],
#  [(0, 0.02083333333333333),
#   (1, 0.7986111111111109),
#   (2, 0.039351851851851846),
#   (3, 0.02083333333333333),
#   (4, 0.039351851851851846),
#   (5, 0.02083333333333333),
#   (6, 0.039351851851851846),
#   (7, 0.02083333333333333)],
#  [(0, 0.017857142857142856),
#   (1, 0.16071428571428573),
#   (2, 0.017857142857142856),
#   (3, 0.017857142857142856),
#   (4, 0.7321428571428571),
#   (5, 0.017857142857142856),
#   (6, 0.017857142857142856),
#   (7, 0.017857142857142856)],
#  [(0, 0.018274853801169593),
#   (1, 0.45102339181286555),
#   (2, 0.018274853801169593),
#   (3, 0.006578947368421053),
#   (4, 0.006578947368421053),
#   (5, 0.006578947368421053),
#   (6, 0.4744152046783626),
#   (7, 0.018274853801169593)],
#  [(0, 0.015625),
#   (1, 0.015625),
#   (2, 0.029513888888888888),
#   (3, 0.015625),
#   (4, 0.6128472222222222),
#   (5, 0.029513888888888888),
#   (6, 0.265625),
#   (7, 0.015625)],
#  [(0, 0.03125),
#   (1, 0.03125),
#   (2, 0.5034722222222222),
#   (3, 0.03125),
#   (4, 0.08680555555555555),
#   (5, 0.03125),
#   (6, 0.059027777777777776),
#   (7, 0.22569444444444445)],
#  [(0, 0.005902777777777778),
#   (1, 0.3392361111111111),
#   (2, 0.003125),
#   (3, 0.21145833333333333),
#   (4, 0.09479166666666666),
#   (5, 0.01423611111111111),
#   (6, 0.30868055555555557),
#   (7, 0.022569444444444444)],
#  [(0, 0.029970760233918127),
#   (1, 0.4334795321637427),
#   (2, 0.012426900584795321),
#   (3, 0.3340643274853801),
#   (4, 0.1527777777777778),
#   (5, 0.012426900584795321),
#   (6, 0.01827485380116959),
#   (7, 0.006578947368421052)],
#  [(0, 0.0078125),
#   (1, 0.5494791666666666),
#   (2, 0.028645833333333332),
#   (3, 0.0078125),
#   (4, 0.0078125),
#   (5, 0.0078125),
#   (6, 0.3828125),
#   (7, 0.0078125)],
#  [(0, 0.1571969696969697),
#   (1, 0.005681818181818182),
#   (2, 0.2935606060606061),
#   (3, 0.005681818181818182),
#   (4, 0.09154040404040405),
#   (5, 0.09154040404040405),
#   (6, 0.3491161616161616),
#   (7, 0.005681818181818182)],
#  [(0, 0.006578947368421052),
#   (1, 0.006578947368421052),
#   (2, 0.02412280701754386),
#   (3, 0.006578947368421052),
#   (4, 0.006578947368421052),
#   (5, 0.2580409356725146),
#   (6, 0.6732456140350878),
#   (7, 0.01827485380116959)],
#  ...]

# %%
topic_df = pd.DataFrame()

# %%
for i, topic_vector in enumerate(topics):
    topic_list = []
    topic_vector = sorted(topic_vector, key = lambda topic: (topic[1]), reverse=True)
    for j, (topic_num, prob) in enumerate(topic_vector):
        prob = round(prob,2)*100
        if(prob > 14):
            topic = "Topic " + str(topic_num)
            topic_list.append(topic)
        else:
            break
    topics_col = ", ".join([topic for topic in topic_list])
    if(i%1000==0): print(i)
    topic_df = topic_df.append(pd.Series([df.iloc[i]['id'], df.iloc['title'], df.iloc[i]['body'], data.iloc[i]['text'], data.iloc[i]['link'], data.iloc[i]['code'], topics_col, df.iloc[i]['score']]), ignore_index=True)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000

# %%
topic_df
# Out:
#                 0                                                  1  \
# 0      62766758.0  Container-Optimized OS (COS) has several limit...
# 1      62766758.0  I'm pretty sure that in case of Python librari...
# 2      62742938.0  The standard library has a module runpy for th...
# 3      62741826.0  Hello and welcome to StackOverflow.In pandas t...
# 4      62741826.0  I guess you want to groupby and exclude all th...
# ...           ...                                                ...
# 99995  35898687.0  Just for fun non-UDF solution:So it just:unrol...
# 99996  35898687.0  The following code does the requested task. An...
# 99997  35937882.0  At the end of your code, just add window.mainl...
# 99998  35937882.0  You didn't do a at the end. Check the Tkinter ...
# 99999  35733050.0  Whenever faced with a complex XML, consider an...
#
#                                                        2  \
# 0      https://cloud.google.com/container-optimized-o...
# 1
# 2           https://docs.python.org/3/library/runpy.html
# 3
# 4
# ...                                                  ...
# 99995
# 99996
# 99997
# 99998     https://docs.python.org/2/library/tkinter.html
# 99999         https://www.w3.org/TR/xslt http://lxml.de/
#
#                                                        3  \
# 0
# 1      failed to map segment from shared object\n.so\...
# 2      runpy\nimport runpy\r\nrunpy.run_module("my_pa...
# 3      groupby\nS\nIn [37]: def my_func(df): \r\n    ...
# 4      groupby\nmixid2\nset_index\nreset_index\ndf = ...
# ...                                                  ...
# 99995  from pyspark.sql.functions import col, first, ...
# 99996  DataFrame\n# Imports\r\nfrom pyspark.sql.types...
# 99997                                  window.mainloop()
# 99998                             window.mainloop() \r\n
# 99999  <xsl:transform xmlns:xsl="http://www.w3.org/19...
#
#                                4
# 0               Topic 2, Topic 1
# 1                        Topic 2
# 2               Topic 0, Topic 2
# 3               Topic 0, Topic 7
# 4                        Topic 7
# ...                          ...
# 99995                    Topic 7
# 99996           Topic 6, Topic 7
# 99997           Topic 6, Topic 4
# 99998
# 99999  Topic 1, Topic 3, Topic 5
#
# [100000 rows x 5 columns]

# %%
topic_df.columns = ['id', 'title', 'body', 'answer', 'link', 'code', 'topic list', 'score']

# %%
topic_df.to_csv('data/keyword_answer.csv', index=False)

# %% [markdown]
# # Creating dataset for topics and its keywords

# %%
keyword_df = pd.DataFrame()

# %%
for topic_num in range(0,8):
    topic_keyword_list = final_model.show_topic(topic_num)
    keyword_list = []
    for word in topic_keyword_list:
        keyword_list.append(word[0])
    keyword_df = keyword_df.append(pd.Series(["Topic "+str(topic_num), keyword_list]), ignore_index=True)

# %%
keyword_df.columns = ['Topic', 'Keywords']

# %%
keyword_df
# Out:
#      Topic                                           Keywords
# 0  Topic 0  [attribute, exception, global, foo, attributes...
# 1  Topic 1  [memory, database, query, table, language, sql...
# 2  Topic 2  [pip, environment, windows, os, packages, fold...
# 3  Topic 3  [match, csv, word, split, encoding, words, exp...
# 4  Topic 4  [request, server, page, url, app, form, templa...
# 5  Topic 5  [plot, matrix, size, shape, axis, graph, scipy...
# 6  Topic 6  [thread, event, window, main, queue, button, w...
# 7  Topic 7  [comprehension, items, item, range, series, so...

# %%
keyword_df.to_csv('data/keywords.csv', index=False)
